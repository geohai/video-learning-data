# %%
import os
import json
import numpy as np
from matplotlib.pyplot import *
import cv2
import torch

CLI_OUTPUT_DIR = "/local/juro4948/data/egoexo4d/egoexo" # Replace with the full path to the --output_directory you pass to the cli
VERSION = "v1"

METADATA_PATH = os.path.join(CLI_OUTPUT_DIR, "takes.json")
ANNOTATIONS_PATH = os.path.join(CLI_OUTPUT_DIR, "annotations")

assert os.path.exists(METADATA_PATH), f"Metadata doesn't exist at {METADATA_PATH}. Is the CLI_OUTPUT_DIR right? Do you satisfy the pre-requisites?"
assert os.path.exists(os.path.join(ANNOTATIONS_PATH, "keystep_train.json")), "Annotation metadata doesn't exist. Did you download it with the CLI?"

# %%
RELEASE_DIR = "/local/juro4948/data/egoexo4d/egoexo"  # NOTE: changeme
assert os.path.exists(RELEASE_DIR), "change RELEASE_DIR to where you downloaded the dataset to"

egoexo = {
    "takes": os.path.join(RELEASE_DIR, "takes.json"),
    # "takes_dropped": os.path.join(RELEASE_DIR, "takes_dropped.json"),
    "captures": os.path.join(RELEASE_DIR, "captures.json"),
    "physical_setting": os.path.join(RELEASE_DIR, "physical_setting.json"),
    "participants": os.path.join(RELEASE_DIR, "participants.json"),
    "visual_objects": os.path.join(RELEASE_DIR, "visual_objects.json"),
}

TASK_ID_CAT = {
    0: "Unknown",
    1000: "Cooking",
    2000: "Health",
    4000: "Bike Repair",
    5000: "Music",
    6000: "Basketball",
    7000: "Rock Climbing",
    8000: "Soccer",
    9000: "Dance",
}

for k, v in egoexo.items():
    egoexo[k] = json.load(open(v))

takes = egoexo["takes"] 
captures = egoexo["captures"]
takes_by_uid = {x["take_uid"]: x for x in takes}

# %% [markdown]
# Filter takes to only include cooking+narration takes

# %%
cooking_takes = [take for take in takes if (take['parent_task_id'] == 1000)]
len(cooking_takes)
# Out:
# 636

# %% [markdown]
# # Prepare dataset for Bridge Prompt pre-training
# - run BrP extract_frames.py on the video files
# - extract action labels to npy

# %% [markdown]
# Configs
# - toggle between ego and exo cameras

# %%
egocentric = True
use_downscaled = False
omnivore_features = True

#  TODO:  we should parse takes.json to get the ego_rgb_code for the rgb aria take. From visual inspection it seems that it's always 214-1, but we should be sure.
if egocentric == True:
    downsample_rate = 1 # this is the sampling factor - take every <rate> samples
    camera = 'aria'
    ego_rgb_code = '214-1' #
    frame_rate = 30  # the raw frame rate ->  4k@60FPS (MP4) for GoPro devices and 1404x1404@30FPS (VRS) for Aria devices (https://docs.ego-exo4d-data.org/overview/#data)

# TODO: fill in values here. Also, how to handle the 60fps vs 30fps issue? Could downsample cam by half
elif egocentric == False and omnivore_features == True:
    camera = 'cam'
    ego_rgb_code = '' 
    frame_rate = 30


elif egocentric == False and omnivore_features == False:
    camera = 'cam'
    ego_rgb_code = '' 
    frame_rate = 60

# %% [markdown]
# ### Read the Annotation File
#
# See this for metatdata: https://docs.ego-exo4d-data.org/annotations/keystep/

# %%
# See raw annotations in this dictionary
keystep_anns = json.load(open(os.path.join(ANNOTATIONS_PATH, "keystep_train.json")))
keystep_anns_val = json.load(open(os.path.join(ANNOTATIONS_PATH, "keystep_val.json")))

anns = keystep_anns["annotations"]
print(f'Length of training items: {len(anns)}')
anns_test = keystep_anns_val["annotations"]

# Add anns_test to anns dictionary
anns.update(anns_test)
print(f'Length of training + val items: {len(anns)}')
# Out:
# Length of training items: 671
# Length of training + val items: 852

# %%
keystep_anns['taxonomy']
# Out:
# {'Covid-19 Rapid Antigen Test': {'0': {'id': 0,
#    'is_leafnode': False,
#    'name': 'Covid-19 Rapid Antigen Test',
#    'parent_id': None,
#    'parent_name': None},
#   '1': {'id': 1,
#    'is_leafnode': False,
#    'name': 'Preparation',
#    'parent_id': 0,
#    'parent_name': 'Covid-19 Rapid Antigen Test'},
#   '2': {'id': 2,
#    'is_leafnode': True,
#    'name': 'Check the expiration date',
#    'parent_id': 1,
#    'parent_name': 'Preparation',
#    'unique_id': 818},
#   '3': {'id': 3,
#    'is_leafnode': True,
#    'name': 'Locate test tube',
#    'parent_id': 1,
#    'parent_name': 'Preparation',
#    'unique_id': 819},
#   '4': {'id': 4,
#    'is_leafnode': True,
#    'name': 'Locate and unwrap test tube cap',
#    'parent_id': 1,
#    'parent_name': 'Preparation',
#    'unique_id': 820},
#   '5': {'id': 5,
#    'is_leafnode': False,
#    'name': 'Unbox the covid19 kit',
#    'parent_id': 1,
#    'parent_name': 'Preparation'},
#   '6': {'id': 6,
#    'is_leafnode': True,
#    'name': 'Arrange test material',
#    'parent_id': 5,
#    'parent_name': 'Unbox the covid19 kit',
#    'unique_id': 821},
#   '7': {'id': 7,
#    'is_leafnode': True,
#    'name': 'Unwrap the testing tube',
#    'parent_id': 5,
#    'parent_name': 'Unbox the covid19 kit',
#    'unique_id': 822},
#   '8': {'id': 8,
#    'is_leafnode': True,
#    'name': 'return the test kit items back into the box',
#    'parent_id': 5,
#    'parent_name': 'Unbox the covid19 kit',
#    'unique_id': 823},
#   '9': {'id': 9,
#    'is_leafnode': False,
#    'name': 'Read the instructions',
#    'parent_id': 1,
#    'parent_name': 'Preparation'},
#   '10': {'id': 10,
#    'is_leafnode': True,
#    'name': 'Read the instructions',
#    'parent_id': 9,
#    'parent_name': 'Read the instructions',
#    'unique_id': 824},
#   '11': {'id': 11,
#    'is_leafnode': True,
#    'name': 'fold the instruction paper',
#    'parent_id': 9,
#    'parent_name': 'Read the instructions',
#    'unique_id': 825},
#   '14': {'id': 14,
#    'is_leafnode': True,
#    'name': 'Get the testing tube',
#    'parent_id': 1,
#    'parent_name': 'Preparation',
#    'unique_id': 828},
#   '15': {'id': 15,
#    'is_leafnode': True,
#    'name': 'Fill the testing with a testing solution',
#    'parent_id': 1,
#    'parent_name': 'Preparation',
#    'unique_id': 829},
#   '16': {'id': 16,
#    'is_leafnode': True,
#    'name': 'Locate and unwrap the collection swab',
#    'parent_id': 1,
#    'parent_name': 'Preparation',
#    'unique_id': 830},
#   '17': {'id': 17,
#    'is_leafnode': True,
#    'name': 'Position the covid 19 test tube on the box',
#    'parent_id': 1,
#    'parent_name': 'Preparation',
#    'unique_id': 863},
#   '18': {'id': 18,
#    'is_leafnode': True,
#    'name': 'carefully open the test tube seal paper',
#    'parent_id': 1,
#    'parent_name': 'Preparation',
#    'unique_id': 832},
#   '19': {'id': 19,
#    'is_leafnode': True,
#    'name': 'Locate and unwrap the test plate',
#    'parent_id': 1,
#    'parent_name': 'Preparation',
#    'unique_id': 833},
#   '20': {'id': 20,
#    'is_leafnode': True,
#    'name': 'cover the test tube',
#    'parent_id': 1,
#    'parent_name': 'Preparation',
#    'unique_id': 834},
#   '21': {'id': 21,
#    'is_leafnode': False,
#    'name': 'Perform sampling',
#    'parent_id': 0,
#    'parent_name': 'Covid-19 Rapid Antigen Test'},
#   '22': {'id': 22,
#    'is_leafnode': True,
#    'name': 'Wrap or Unwrap Covid- 19 Rapid Antigen Test Pack',
#    'parent_id': 21,
#    'parent_name': 'Perform sampling',
#    'unique_id': 835},
#   '23': {'id': 23,
#    'is_leafnode': True,
#    'name': 'Add sealed solution',
#    'parent_id': 21,
#    'parent_name': 'Perform sampling',
#    'unique_id': 836},
#   '24': {'id': 24,
#    'is_leafnode': True,
#    'name': 'Blow nose',
#    'parent_id': 21,
#    'parent_name': 'Perform sampling',
#    'unique_id': 837},
#   '25': {'id': 25,
#    'is_leafnode': True,
#    'name': 'Slowly insert the tip of the swab into the nose',
#    'parent_id': 21,
#    'parent_name': 'Perform sampling',
#    'unique_id': 838},
#   '26': {'id': 26,
#    'is_leafnode': True,
#    'name': 'Rotate and swirl the swab around for 5-10 times',
#    'parent_id': 21,
#    'parent_name': 'Perform sampling',
#    'unique_id': 839},
#   '27': {'id': 27,
#    'is_leafnode': True,
#    'name': 'Slowly extract the swab from the nostril',
#    'parent_id': 21,
#    'parent_name': 'Perform sampling',
#    'unique_id': 840},
#   '28': {'id': 28,
#    'is_leafnode': True,
#    'name': 'Repeat the process with the other nostril',
#    'parent_id': 21,
#    'parent_name': 'Perform sampling',
#    'unique_id': 841},
#   '30': {'id': 30,
#    'is_leafnode': False,
#    'name': 'Prepare materials',
#    'parent_id': 0,
#    'parent_name': 'Covid-19 Rapid Antigen Test'},
#   '31': {'id': 31,
#    'is_leafnode': True,
#    'name': 'Unbox package',
#    'parent_id': 30,
#    'parent_name': 'Prepare materials',
#    'unique_id': 843},
#   '32': {'id': 32,
#    'is_leafnode': True,
#    'name': 'Unwrap testing plate',
#    'parent_id': 30,
#    'parent_name': 'Prepare materials',
#    'unique_id': 844},
#   '33': {'id': 33,
#    'is_leafnode': False,
#    'name': 'Perform testing',
#    'parent_id': 0,
#    'parent_name': 'Covid-19 Rapid Antigen Test'},
#   '34': {'id': 34,
#    'is_leafnode': True,
#    'name': 'Get a timer',
#    'parent_id': 33,
#    'parent_name': 'Perform testing',
#    'unique_id': 845},
#   '35': {'id': 35,
#    'is_leafnode': True,
#    'name': 'Set a timer',
#    'parent_id': 33,
#    'parent_name': 'Perform testing',
#    'unique_id': 503},
#   '36': {'id': 36,
#    'is_leafnode': True,
#    'name': 'Dip the swab into the testing tube',
#    'parent_id': 33,
#    'parent_name': 'Perform testing',
#    'unique_id': 847},
#   '37': {'id': 37,
#    'is_leafnode': True,
#    'name': 'Rotate and swirl the swab around for 5-10 times',
#    'parent_id': 33,
#    'parent_name': 'Perform testing',
#    'unique_id': 839},
#   '38': {'id': 38,
#    'is_leafnode': True,
#    'name': 'Visually inspect the testing tube',
#    'parent_id': 33,
#    'parent_name': 'Perform testing',
#    'unique_id': 849},
#   '39': {'id': 39,
#    'is_leafnode': True,
#    'name': 'Apply a few drops of the testing solution to the testing plate',
#    'parent_id': 33,
#    'parent_name': 'Perform testing',
#    'unique_id': 850},
#   '40': {'id': 40,
#    'is_leafnode': True,
#    'name': 'cover the test tube',
#    'parent_id': 33,
#    'parent_name': 'Perform testing',
#    'unique_id': 834},
#   '41': {'id': 41,
#    'is_leafnode': True,
#    'name': 'Position the covid 19 test tube on the box',
#    'parent_id': 33,
#    'parent_name': 'Perform testing',
#    'unique_id': 863},
#   '42': {'id': 42,
#    'is_leafnode': True,
#    'name': 'Rotate and swirl the swab around for 5-10 times',
#    'parent_id': 33,
#    'parent_name': 'Perform testing',
#    'unique_id': 839},
#   '43': {'id': 43,
#    'is_leafnode': True,
#    'name': 'Set the swab into the testing plate',
#    'parent_id': 33,
#    'parent_name': 'Perform testing',
#    'unique_id': 854},
#   '44': {'id': 44,
#    'is_leafnode': True,
#    'name': 'Cover the testing plate',
#    'parent_id': 33,
#    'parent_name': 'Perform testing',
#    'unique_id': 855},
#   '45': {'id': 45,
#    'is_leafnode': True,
#    'name': 'Wait for the testing solution incubation time',
#    'parent_id': 33,
#    'parent_name': 'Perform testing',
#    'unique_id': 856},
#   '46': {'id': 46,
#    'is_leafnode': True,
#    'name': 'Open the test tube lid',
#    'parent_id': 33,
#    'parent_name': 'Perform testing',
#    'unique_id': 857},
#   '47': {'id': 47,
#    'is_leafnode': True,
#    'name': 'Fold package box',
#    'parent_id': 33,
#    'parent_name': 'Perform testing',
#    'unique_id': 858},
#   '48': {'id': 48,
#    'is_leafnode': True,
#    'name': 'Locate and unwrap the test strip',
#    'parent_id': 33,
#    'parent_name': 'Perform testing',
#    'unique_id': 859},
#   '49': {'id': 49,
#    'is_leafnode': True,
#    'name': 'Remove the swab from the testing tube',
#    'parent_id': 33,
#    'parent_name': 'Perform testing',
#    'unique_id': 860},
#   '50': {'id': 50,
#    'is_leafnode': True,
#    'name': 'Dip the test strip into the testing tube',
#    'parent_id': 33,
#    'parent_name': 'Perform testing',
#    'unique_id': 861},
#   '51': {'id': 51,
#    'is_leafnode': True,
#    'name': 'Shake the test tube',
#    'parent_id': 33,
#    'parent_name': 'Perform testing',
#    'unique_id': 862},
#   '52': {'id': 52,
#    'is_leafnode': True,
#    'name': 'Position the covid 19 test tube on the box',
#    'parent_id': 33,
#    'parent_name': 'Perform testing',
#    'unique_id': 863},
#   '53': {'id': 53,
#    'is_leafnode': True,
#    'name': 'Stop timer',
#    'parent_id': 33,
#    'parent_name': 'Perform testing',
#    'unique_id': 864},
#   '54': {'id': 54,
#    'is_leafnode': True,
#    'name': 'Wait for 15 minutes',
#    'parent_id': 33,
#    'parent_name': 'Perform testing',
#    'unique_id': 867},
#   '55': {'id': 55,
#    'is_leafnode': True,
#    'name': 'Check solutions tube',
#    'parent_id': 33,
#    'parent_name': 'Perform testing',
#    'unique_id': 866},
#   '56': {'id': 56,
#    'is_leafnode': False,
#    'name': 'Check results',
#    'parent_id': 0,
#    'parent_name': 'Covid-19 Rapid Antigen Test'},
#   '57': {'id': 57,
#    'is_leafnode': True,
#    'name': 'Wait for 15 minutes',
#    'parent_id': 56,
#    'parent_name': 'Check results',
#    'unique_id': 867},
#   '58': {'id': 58,
#    'is_leafnode': True,
#    'name': 'Check the testing plate',
#    'parent_id': 56,
#    'parent_name': 'Check results',
#    'unique_id': 868},
#   '59': {'id': 59,
#    'is_leafnode': True,
#    'name': 'Dispose waste',
#    'parent_id': 0,
#    'parent_name': 'Covid-19 Rapid Antigen Test',
#    'unique_id': 869},
#   '60': {'id': 60,
#    'is_leafnode': False,
#    'name': 'Arrange test materials in the ziploc bag for disposal',
#    'parent_id': 0,
#    'parent_name': 'Covid-19 Rapid Antigen Test'},
#   '61': {'id': 61,
#    'is_leafnode': True,
#    'name': 'Mistake',
#    'parent_id': 0,
#    'parent_name': 'Covid-19 Rapid Antigen Test',
#    'unique_id': 10000},
#   '63': {'id': 63,
#    'name': 'Unfold the instruction paper',
#    'parent_id': 9,
#    'parent_name': 'Read the instructions',
#    'is_leafnode': True,
#    'unique_id': 871},
#   '64': {'id': 64,
#    'name': 'Collect saliva sample',
#    'parent_id': 21,
#    'parent_name': 'Perform sampling',
#    'is_leafnode': True,
#    'unique_id': 872},
#   '65': {'id': 65,
#    'name': 'Slowly extract the test tube from the mouth',
#    'parent_id': 33,
#    'parent_name': 'Perform testing',
#    'is_leafnode': True,
#    'unique_id': 873},
#   '66': {'id': 66,
#    'name': 'Spit into the testing tube',
#    'parent_id': 33,
#    'parent_name': 'Perform testing',
#    'is_leafnode': True,
#    'unique_id': 874},
#   '67': {'id': 67,
#    'is_leafnode': True,
#    'name': 'carefully open the test tube seal paper',
#    'parent_id': 33,
#    'parent_name': 'Perform testing',
#    'unique_id': 832},
#   '68': {'id': 68,
#    'is_leafnode': True,
#    'name': 'Position the covid 19 test tube on the box',
#    'parent_id': 21,
#    'parent_name': 'Perform sampling',
#    'unique_id': 863},
#   '69': {'id': 69,
#    'is_leafnode': True,
#    'name': 'Dispose waste',
#    'parent_id': 33,
#    'parent_name': 'Perform testing',
#    'unique_id': 869},
#   '70': {'id': 70,
#    'is_leafnode': True,
#    'name': 'Dispose waste',
#    'parent_id': 60,
#    'parent_name': 'Arrange test materials in the ziploc bag for disposal',
#    'unique_id': 869},
#   '71': {'id': 71,
#    'is_leafnode': True,
#    'name': 'fold the instruction paper',
#    'parent_id': 33,
#    'parent_name': 'Perform testing',
#    'unique_id': 825},
#   '72': {'id': 72,
#    'is_leafnode': True,
#    'name': 'Check the testing plate',
#    'parent_id': 33,
#    'parent_name': 'Perform testing',
#    'unique_id': 868},
#   '73': {'id': 73,
#    'is_leafnode': True,
#    'name': 'Shake the test tube',
#    'parent_id': 1,
#    'parent_name': 'Preparation',
#    'unique_id': 862},
#   '74': {'id': 74,
#    'is_leafnode': True,
#    'name': 'Fill the testing with a testing solution',
#    'parent_id': 21,
#    'parent_name': 'Perform sampling',
#    'unique_id': 829},
#   '75': {'id': 75,
#    'is_leafnode': True,
#    'name': 'Position the covid 19 test tube on the box',
#    'parent_id': 21,
#    'parent_name': 'Perform sampling',
#    'unique_id': 863},
#   '76': {'id': 76,
#    'is_leafnode': True,
#    'name': 'fold the instruction paper',
#    'parent_id': 21,
#    'parent_name': 'Perform sampling',
#    'unique_id': 825},
#   '77': {'id': 77,
#    'is_leafnode': True,
#    'name': 'return the test kit items back into the box',
#    'parent_id': 21,
#    'parent_name': 'Perform sampling',
#    'unique_id': 823},
#   '78': {'id': 78,
#    'is_leafnode': True,
#    'name': 'Unwrap testing plate',
#    'parent_id': 33,
#    'parent_name': 'Perform testing',
#    'unique_id': 844},
#   '79': {'id': 79,
#    'is_leafnode': True,
#    'name': 'Wait for 15 minutes',
#    'parent_id': 21,
#    'parent_name': 'Perform sampling',
#    'unique_id': 867},
#   '80': {'id': 80,
#    'is_leafnode': True,
#    'name': 'Locate and unwrap the test plate',
#    'parent_id': 33,
#    'parent_name': 'Perform testing',
#    'unique_id': 833},
#   '81': {'id': 81,
#    'is_leafnode': True,
#    'name': 'Open the test tube lid',
#    'parent_id': 1,
#    'parent_name': 'Preparation',
#    'unique_id': 857},
#   '82': {'id': 82,
#    'is_leafnode': True,
#    'name': 'Dispose waste',
#    'parent_id': 1,
#    'parent_name': 'Preparation',
#    'unique_id': 869},
#   '83': {'id': 83,
#    'is_leafnode': True,
#    'name': 'Dispose waste',
#    'parent_id': 21,
#    'parent_name': 'Perform sampling',
#    'unique_id': 869},
#   '84': {'id': 84,
#    'is_leafnode': True,
#    'name': 'Position the covid 19 test tube on the box',
#    'parent_id': 1,
#    'parent_name': 'Preparation',
#    'unique_id': 863},
#   '85': {'id': 85,
#    'is_leafnode': True,
#    'name': 'Get the testing tube',
#    'parent_id': 33,
#    'parent_name': 'Perform testing',
#    'unique_id': 828},
#   '86': {'id': 86,
#    'is_leafnode': True,
#    'name': 'Visually inspect the testing tube',
#    'parent_id': 1,
#    'parent_name': 'Preparation',
#    'unique_id': 849},
#   '87': {'id': 87,
#    'is_leafnode': True,
#    'name': 'Rotate and swirl the swab around for 5-10 times',
#    'parent_id': 33,
#    'parent_name': 'Perform testing',
#    'unique_id': 839}},
#  'Fix a Flat Tire - Replace a Bike Tube': {'0': {'id': 0,
#    'is_leafnode': False,
#    'name': 'Fix a Flat Tire - Replace a Bike Tube',
#    'parent_id': None,
#    'parent_name': None},
#   '1': {'id': 1,
#    'is_leafnode': False,
#    'name': 'Inspect the tube',
#    'parent_id': 0,
#    'parent_name': 'Fix a Flat Tire - Replace a Bike Tube'},
#   '2': {'id': 2,
#    'is_leafnode': False,
#    'name': 'Remove tube',
#    'parent_id': 0,
#    'parent_name': 'Fix a Flat Tire - Replace a Bike Tube'},
#   '3': {'id': 3,
#    'is_leafnode': False,
#    'name': 'Deflate the tube',
#    'parent_id': 2,
#    'parent_name': 'Remove tube'},
#   '4': {'id': 4,
#    'is_leafnode': True,
#    'name': 'Remove dust cap from the wheel',
#    'parent_id': 3,
#    'parent_name': 'Deflate the tube',
#    'unique_id': 875},
#   '5': {'id': 5,
#    'is_leafnode': True,
#    'name': 'Remove presta valve from the wheel',
#    'parent_id': 3,
#    'parent_name': 'Deflate the tube',
#    'unique_id': 876},
#   '6': {'id': 6,
#    'is_leafnode': True,
#    'name': 'Remove stem nut from the wheel',
#    'parent_id': 3,
#    'parent_name': 'Deflate the tube',
#    'unique_id': 877},
#   '7': {'id': 7,
#    'is_leafnode': True,
#    'name': 'Loosen and unthread the lock nut at the valve stem',
#    'parent_id': 3,
#    'parent_name': 'Deflate the tube',
#    'unique_id': 878},
#   '8': {'id': 8,
#    'is_leafnode': True,
#    'name': 'Squeeze out any air inside the tube',
#    'parent_id': 3,
#    'parent_name': 'Deflate the tube',
#    'unique_id': 879},
#   '9': {'id': 9,
#    'is_leafnode': False,
#    'name': 'Loosen the bead from against the rim sidewall',
#    'parent_id': 2,
#    'parent_name': 'Remove tube'},
#   '10': {'id': 10,
#    'is_leafnode': True,
#    'name': 'Get bike tire lever',
#    'parent_id': 9,
#    'parent_name': 'Loosen the bead from against the rim sidewall',
#    'unique_id': 911},
#   '11': {'id': 11,
#    'is_leafnode': True,
#    'name': 'Engage a tire lever anywhere on the rim except right at the valve',
#    'parent_id': 9,
#    'parent_name': 'Loosen the bead from against the rim sidewall',
#    'unique_id': 881},
#   '12': {'id': 12,
#    'is_leafnode': True,
#    'name': 'Pull back and lift the bead out of the rim',
#    'parent_id': 9,
#    'parent_name': 'Loosen the bead from against the rim sidewall',
#    'unique_id': 882},
#   '13': {'id': 13,
#    'is_leafnode': False,
#    'name': 'Remove inner tube',
#    'parent_id': 0,
#    'parent_name': 'Fix a Flat Tire - Replace a Bike Tube'},
#   '14': {'id': 14,
#    'is_leafnode': True,
#    'name': 'Use the tire lever around the rim until the tube is complete off the wheel',
#    'parent_id': 13,
#    'parent_name': 'Remove inner tube',
#    'unique_id': 883},
#   '15': {'id': 15,
#    'is_leafnode': True,
#    'name': 'Push the valve through its hole',
#    'parent_id': 13,
#    'parent_name': 'Remove inner tube',
#    'unique_id': 884},
#   '16': {'id': 16,
#    'is_leafnode': True,
#    'name': 'Pull the inner tube out',
#    'parent_id': 13,
#    'parent_name': 'Remove inner tube',
#    'unique_id': 885},
#   '17': {'id': 17,
#    'is_leafnode': False,
#    'name': 'Inspect the tire',
#    'parent_id': 0,
#    'parent_name': 'Fix a Flat Tire - Replace a Bike Tube'},
#   '18': {'id': 18,
#    'is_leafnode': True,
#    'name': 'Check for any damage or splits in the thread',
#    'parent_id': 17,
#    'parent_name': 'Inspect the tire',
#    'unique_id': 886},
#   '19': {'id': 19,
#    'is_leafnode': True,
#    'name': 'Remove any thorns, nails, etc. that could puncture the fresh tube later',
#    'parent_id': 17,
#    'parent_name': 'Inspect the tire',
#    'unique_id': 887},
#   '20': {'id': 20,
#    'is_leafnode': False,
#    'name': 'Fit a new inner tube and tire to a wheel',
#    'parent_id': 0,
#    'parent_name': 'Fix a Flat Tire - Replace a Bike Tube'},
#   '21': {'id': 21,
#    'is_leafnode': True,
#    'name': 'Get a new inner tube',
#    'parent_id': 20,
#    'parent_name': 'Fit a new inner tube and tire to a wheel',
#    'unique_id': 888},
#   '22': {'id': 22,
#    'is_leafnode': True,
#    'name': 'Fix stem nut to the wheel',
#    'parent_id': 20,
#    'parent_name': 'Fit a new inner tube and tire to a wheel',
#    'unique_id': 889},
#   '23': {'id': 23,
#    'is_leafnode': True,
#    'name': 'Inflate the inner tube a little',
#    'parent_id': 20,
#    'parent_name': 'Fit a new inner tube and tire to a wheel',
#    'unique_id': 890},
#   '24': {'id': 24,
#    'is_leafnode': True,
#    'name': 'Tighten the Dust Cap',
#    'parent_id': 20,
#    'parent_name': 'Fit a new inner tube and tire to a wheel',
#    'unique_id': 891},
#   '25': {'id': 25,
#    'is_leafnode': True,
#    'name': 'Attach dust cap to the valve of the wheel',
#    'parent_id': 20,
#    'parent_name': 'Fit a new inner tube and tire to a wheel',
#    'unique_id': 892},
#   '26': {'id': 26,
#    'is_leafnode': True,
#    'name': 'Remove the valve cap',
#    'parent_id': 20,
#    'parent_name': 'Fit a new inner tube and tire to a wheel',
#    'unique_id': 893},
#   '28': {'id': 28,
#    'is_leafnode': True,
#    'name': 'Apply the dust cap',
#    'parent_id': 20,
#    'parent_name': 'Fit a new inner tube and tire to a wheel',
#    'unique_id': 895},
#   '29': {'id': 29,
#    'is_leafnode': True,
#    'name': 'Remove the dust cap',
#    'parent_id': 20,
#    'parent_name': 'Fit a new inner tube and tire to a wheel',
#    'unique_id': 896},
#   '30': {'id': 30,
#    'is_leafnode': True,
#    'name': 'Unpack the new tube',
#    'parent_id': 20,
#    'parent_name': 'Fit a new inner tube and tire to a wheel',
#    'unique_id': 897},
#   '31': {'id': 31,
#    'is_leafnode': True,
#    'name': 'Deflate the tube',
#    'parent_id': 20,
#    'parent_name': 'Fit a new inner tube and tire to a wheel',
#    'unique_id': 920},
#   '32': {'id': 32,
#    'is_leafnode': True,
#    'name': 'Engage the valve stem into the rim',
#    'parent_id': 20,
#    'parent_name': 'Fit a new inner tube and tire to a wheel',
#    'unique_id': 899},
#   '33': {'id': 33,
#    'is_leafnode': True,
#    'name': 'Fit the tube to the wheel',
#    'parent_id': 20,
#    'parent_name': 'Fit a new inner tube and tire to a wheel',
#    'unique_id': 900},
#   '34': {'id': 34,
#    'is_leafnode': True,
#    'name': 'Fit the tire to the wheel',
#    'parent_id': 20,
#    'parent_name': 'Fit a new inner tube and tire to a wheel',
#    'unique_id': 901},
#   '35': {'id': 35,
#    'is_leafnode': True,
#    'name': 'Partially inflate the the tube to check the bead is properly seated',
#    'parent_id': 20,
#    'parent_name': 'Fit a new inner tube and tire to a wheel',
#    'unique_id': 902},
#   '36': {'id': 36,
#    'is_leafnode': False,
#    'name': 'Inspect the bead seat line for irregularities',
#    'parent_id': 20,
#    'parent_name': 'Fit a new inner tube and tire to a wheel'},
#   '37': {'id': 37,
#    'is_leafnode': True,
#    'name': 'If the bead rises up in one spot, deflate the inner tube and push it back down to reseat the bead',
#    'parent_id': 36,
#    'parent_name': 'Inspect the bead seat line for irregularities',
#    'unique_id': 903},
#   '39': {'id': 39,
#    'is_leafnode': True,
#    'name': 'Inspect the bead seat line',
#    'parent_id': 36,
#    'parent_name': 'Inspect the bead seat line for irregularities',
#    'unique_id': 905},
#   '40': {'id': 40,
#    'is_leafnode': True,
#    'name': 'Fully inflate the tire',
#    'parent_id': 20,
#    'parent_name': 'Fit a new inner tube and tire to a wheel',
#    'unique_id': 906},
#   '42': {'id': 42,
#    'name': 'Check for any damage or splits in the tube',
#    'parent_id': 1,
#    'parent_name': 'Inspect the tube',
#    'is_leafnode': True,
#    'unique_id': 907},
#   '44': {'id': 44,
#    'name': 'Remove stem nut from the wheel',
#    'parent_id': 20,
#    'parent_name': 'Fit a new inner tube and tire to a wheel',
#    'is_leafnode': True,
#    'unique_id': 877},
#   '45': {'id': 45,
#    'is_leafnode': True,
#    'name': 'Remove stem nut from the wheel',
#    'parent_id': 20,
#    'parent_name': 'Fit a new inner tube and tire to a wheel',
#    'unique_id': 877},
#   '46': {'id': 46,
#    'is_leafnode': True,
#    'name': 'Pull the inner tube out',
#    'parent_id': 20,
#    'parent_name': 'Fit a new inner tube and tire to a wheel',
#    'unique_id': 885},
#   '47': {'id': 47,
#    'is_leafnode': True,
#    'name': 'Pull back and lift the bead out of the rim',
#    'parent_id': 20,
#    'parent_name': 'Fit a new inner tube and tire to a wheel',
#    'unique_id': 882},
#   '48': {'id': 48,
#    'is_leafnode': True,
#    'name': 'Check for any damage or splits in the thread',
#    'parent_id': 1,
#    'parent_name': 'Inspect the tube',
#    'unique_id': 886}},
#  'Remove a Wheel': {'0': {'id': 0,
#    'is_leafnode': False,
#    'name': 'Remove a Wheel',
#    'parent_id': None,
#    'parent_name': None},
#   '1': {'id': 1,
#    'is_leafnode': False,
#    'name': 'Get the tools and supplies ready',
#    'parent_id': 0,
#    'parent_name': 'Remove a Wheel'},
#   '2': {'id': 2,
#    'is_leafnode': True,
#    'name': 'Get appropriate wrenches',
#    'parent_id': 1,
#    'parent_name': 'Get the tools and supplies ready',
#    'unique_id': 910},
#   '4': {'id': 4,
#    'is_leafnode': True,
#    'name': 'Get bike air pump',
#    'parent_id': 1,
#    'parent_name': 'Get the tools and supplies ready',
#    'unique_id': 925},
#   '5': {'id': 5,
#    'is_leafnode': False,
#    'name': 'Get the bike ready for wheel removal',
#    'parent_id': 0,
#    'parent_name': 'Remove a Wheel'},
#   '6': {'id': 6,
#    'is_leafnode': True,
#    'name': 'Shift the gear to the smallest cog',
#    'parent_id': 5,
#    'parent_name': 'Get the bike ready for wheel removal',
#    'unique_id': 913},
#   '7': {'id': 7,
#    'is_leafnode': True,
#    'name': 'Release caliper rim brake pads',
#    'parent_id': 5,
#    'parent_name': 'Get the bike ready for wheel removal',
#    'unique_id': 914},
#   '8': {'id': 8,
#    'is_leafnode': True,
#    'name': 'Pivot the derailleur back',
#    'parent_id': 5,
#    'parent_name': 'Get the bike ready for wheel removal',
#    'unique_id': 915},
#   '9': {'id': 9,
#    'is_leafnode': False,
#    'name': 'Get the bike off the ground',
#    'parent_id': 5,
#    'parent_name': 'Get the bike ready for wheel removal'},
#   '10': {'id': 10,
#    'is_leafnode': True,
#    'name': 'Put the bike on a bike repair stand',
#    'parent_id': 9,
#    'parent_name': 'Get the bike off the ground',
#    'unique_id': 916},
#   '11': {'id': 11,
#    'is_leafnode': True,
#    'name': 'Put the bike upside down',
#    'parent_id': 9,
#    'parent_name': 'Get the bike off the ground',
#    'unique_id': 917},
#   '12': {'id': 12,
#    'is_leafnode': False,
#    'name': 'Remove the wheel',
#    'parent_id': 0,
#    'parent_name': 'Remove a Wheel'},
#   '13': {'id': 13,
#    'is_leafnode': True,
#    'name': 'Pull the release lever outwards',
#    'parent_id': 12,
#    'parent_name': 'Remove the wheel',
#    'unique_id': 918},
#   '14': {'id': 14,
#    'is_leafnode': True,
#    'name': 'Loosen both axle nuts using a wrench',
#    'parent_id': 12,
#    'parent_name': 'Remove the wheel',
#    'unique_id': 919},
#   '16': {'id': 16,
#    'name': 'Deflate the tube',
#    'parent_id': 5,
#    'parent_name': 'Get the bike ready for wheel removal',
#    'is_leafnode': True,
#    'unique_id': 920},
#   '17': {'id': 17,
#    'name': 'Loosen the axle nuts',
#    'parent_id': 12,
#    'parent_name': 'Remove the wheel',
#    'is_leafnode': True,
#    'unique_id': 951},
#   '18': {'id': 18,
#    'name': 'Pull out the wheel from the bicycle frame',
#    'parent_id': 12,
#    'parent_name': 'Remove the wheel',
#    'is_leafnode': True,
#    'unique_id': 922},
#   '19': {'id': 19,
#    'is_leafnode': True,
#    'name': 'Release caliper rim brake pads',
#    'parent_id': 0,
#    'parent_name': 'Remove a Wheel',
#    'unique_id': 914},
#   '20': {'id': 20,
#    'is_leafnode': True,
#    'name': 'Get a marker',
#    'parent_id': 1,
#    'parent_name': 'Get the tools and supplies ready',
#    'unique_id': 2320},
#   '21': {'id': 21,
#    'is_leafnode': True,
#    'name': 'Pull the lever outward and turn the axle CCW until axle can be removed',
#    'parent_id': 12,
#    'parent_name': 'Remove the wheel',
#    'unique_id': 2321}},
#  'Install a Wheel': {'0': {'id': 0,
#    'is_leafnode': False,
#    'name': 'Install a Wheel',
#    'parent_id': None,
#    'parent_name': None},
#   '1': {'id': 1,
#    'is_leafnode': False,
#    'name': 'Get the tools and supplies ready',
#    'parent_id': 0,
#    'parent_name': 'Install a Wheel'},
#   '2': {'id': 2,
#    'is_leafnode': True,
#    'name': 'Get appropriate wrenches',
#    'parent_id': 1,
#    'parent_name': 'Get the tools and supplies ready',
#    'unique_id': 910},
#   '3': {'id': 3,
#    'is_leafnode': True,
#    'name': 'Get bike tire lever',
#    'parent_id': 1,
#    'parent_name': 'Get the tools and supplies ready',
#    'unique_id': 911},
#   '4': {'id': 4,
#    'is_leafnode': True,
#    'name': 'Get bike air pump',
#    'parent_id': 1,
#    'parent_name': 'Get the tools and supplies ready',
#    'unique_id': 925},
#   '6': {'id': 6,
#    'is_leafnode': True,
#    'name': 'Return wrenches',
#    'parent_id': 1,
#    'parent_name': 'Get the tools and supplies ready',
#    'unique_id': 927},
#   '7': {'id': 7,
#    'is_leafnode': True,
#    'name': 'Get bike wheel',
#    'parent_id': 1,
#    'parent_name': 'Get the tools and supplies ready',
#    'unique_id': 928},
#   '8': {'id': 8,
#    'is_leafnode': False,
#    'name': 'Get the bike ready for wheel insert',
#    'parent_id': 0,
#    'parent_name': 'Install a Wheel'},
#   '9': {'id': 9,
#    'is_leafnode': True,
#    'name': 'Put the wheel fully seated into the fork',
#    'parent_id': 8,
#    'parent_name': 'Get the bike ready for wheel insert',
#    'unique_id': 929},
#   '10': {'id': 10,
#    'is_leafnode': False,
#    'name': 'Get the bike off the ground',
#    'parent_id': 8,
#    'parent_name': 'Get the bike ready for wheel insert'},
#   '11': {'id': 11,
#    'is_leafnode': True,
#    'name': 'Put the bike on a bike repair stand',
#    'parent_id': 10,
#    'parent_name': 'Get the bike off the ground',
#    'unique_id': 916},
#   '12': {'id': 12,
#    'is_leafnode': True,
#    'name': 'Put the bike upside down',
#    'parent_id': 10,
#    'parent_name': 'Get the bike off the ground',
#    'unique_id': 917},
#   '13': {'id': 13,
#    'is_leafnode': True,
#    'name': 'Get the wheel',
#    'parent_id': 8,
#    'parent_name': 'Get the bike ready for wheel insert',
#    'unique_id': 932},
#   '14': {'id': 14,
#    'is_leafnode': True,
#    'name': 'Put the wheel fully seated into the fork',
#    'parent_id': 8,
#    'parent_name': 'Get the bike ready for wheel insert',
#    'unique_id': 929},
#   '15': {'id': 15,
#    'is_leafnode': False,
#    'name': 'Install the wheel',
#    'parent_id': 0,
#    'parent_name': 'Install a Wheel'},
#   '16': {'id': 16,
#    'is_leafnode': True,
#    'name': 'Push the release lever inwards',
#    'parent_id': 15,
#    'parent_name': 'Install the wheel',
#    'unique_id': 934},
#   '17': {'id': 17,
#    'is_leafnode': True,
#    'name': 'Tighten both axle nuts using a wrench',
#    'parent_id': 15,
#    'parent_name': 'Install the wheel',
#    'unique_id': 935},
#   '18': {'id': 18,
#    'is_leafnode': True,
#    'name': 'Push the level inward and turn the axle CW to tighten',
#    'parent_id': 15,
#    'parent_name': 'Install the wheel',
#    'unique_id': 936},
#   '19': {'id': 19,
#    'is_leafnode': True,
#    'name': 'Pivot the derailleur back',
#    'parent_id': 15,
#    'parent_name': 'Install the wheel',
#    'unique_id': 915},
#   '20': {'id': 20,
#    'is_leafnode': True,
#    'name': 'Tighten the brake cable to the rear axle',
#    'parent_id': 15,
#    'parent_name': 'Install the wheel',
#    'unique_id': 938},
#   '21': {'id': 21,
#    'is_leafnode': True,
#    'name': 'Tighten the break pads',
#    'parent_id': 15,
#    'parent_name': 'Install the wheel',
#    'unique_id': 939},
#   '22': {'id': 22,
#    'is_leafnode': True,
#    'name': 'Roll the wheel',
#    'parent_id': 15,
#    'parent_name': 'Install the wheel',
#    'unique_id': 940},
#   '23': {'id': 23,
#    'is_leafnode': True,
#    'name': 'Rotate the wheel',
#    'parent_id': 15,
#    'parent_name': 'Install the wheel',
#    'unique_id': 941},
#   '24': {'id': 24,
#    'is_leafnode': True,
#    'name': 'Connect the brake noodle',
#    'parent_id': 15,
#    'parent_name': 'Install the wheel',
#    'unique_id': 942},
#   '25': {'id': 25,
#    'is_leafnode': True,
#    'name': 'Squeeze the brake',
#    'parent_id': 15,
#    'parent_name': 'Install the wheel',
#    'unique_id': 947},
#   '26': {'id': 26,
#    'is_leafnode': True,
#    'name': 'Check the both hand brakes',
#    'parent_id': 15,
#    'parent_name': 'Install the wheel',
#    'unique_id': 944},
#   '27': {'id': 27,
#    'is_leafnode': True,
#    'name': 'Clip the wheel to the hub and axle',
#    'parent_id': 15,
#    'parent_name': 'Install the wheel',
#    'unique_id': 945},
#   '28': {'id': 28,
#    'is_leafnode': True,
#    'name': 'Rotate the pedal',
#    'parent_id': 15,
#    'parent_name': 'Install the wheel',
#    'unique_id': 946},
#   '29': {'id': 29,
#    'is_leafnode': True,
#    'name': 'Squeeze the brake',
#    'parent_id': 15,
#    'parent_name': 'Install the wheel',
#    'unique_id': 947},
#   '30': {'id': 30,
#    'is_leafnode': True,
#    'name': 'Check the brake',
#    'parent_id': 15,
#    'parent_name': 'Install the wheel',
#    'unique_id': 948},
#   '31': {'id': 31,
#    'is_leafnode': True,
#    'name': 'Clip the brake to the wheel',
#    'parent_id': 15,
#    'parent_name': 'Install the wheel',
#    'unique_id': 949},
#   '32': {'id': 32,
#    'is_leafnode': True,
#    'name': 'Hold hand brake',
#    'parent_id': 15,
#    'parent_name': 'Install the wheel',
#    'unique_id': 950},
#   '33': {'id': 33,
#    'is_leafnode': True,
#    'name': 'Loosen the axle nuts',
#    'parent_id': 15,
#    'parent_name': 'Install the wheel',
#    'unique_id': 951},
#   '34': {'id': 34,
#    'is_leafnode': True,
#    'name': 'Lift the wheel into the fork with the wheel axles into the fork slot',
#    'parent_id': 15,
#    'parent_name': 'Install the wheel',
#    'unique_id': 952},
#   '35': {'id': 35,
#    'is_leafnode': True,
#    'name': 'Return wrenches',
#    'parent_id': 15,
#    'parent_name': 'Install the wheel',
#    'unique_id': 927},
#   '36': {'id': 36,
#    'is_leafnode': True,
#    'name': 'Connect the brake noodle',
#    'parent_id': 15,
#    'parent_name': 'Install the wheel',
#    'unique_id': 942},
#   '37': {'id': 37,
#    'is_leafnode': True,
#    'name': 'Check the wheel',
#    'parent_id': 15,
#    'parent_name': 'Install the wheel',
#    'unique_id': 955},
#   '39': {'id': 39,
#    'name': 'Deflate the tire',
#    'parent_id': 8,
#    'parent_name': 'Get the bike ready for wheel insert',
#    'is_leafnode': True,
#    'unique_id': 956},
#   '40': {'id': 40,
#    'is_leafnode': True,
#    'name': 'Put the bike upside down',
#    'parent_id': 15,
#    'parent_name': 'Install the wheel',
#    'unique_id': 917},
#   '41': {'id': 41,
#    'is_leafnode': True,
#    'name': 'Put the bike on a bike repair stand',
#    'parent_id': 15,
#    'parent_name': 'Install the wheel',
#    'unique_id': 916},
#   '42': {'id': 42,
#    'is_leafnode': True,
#    'name': 'Get appropriate wrenches',
#    'parent_id': 15,
#    'parent_name': 'Install the wheel',
#    'unique_id': 910},
#   '43': {'id': 43,
#    'is_leafnode': True,
#    'name': 'Get bike air pump',
#    'parent_id': 15,
#    'parent_name': 'Install the wheel',
#    'unique_id': 925},
#   '44': {'id': 44,
#    'name': 'Get thru-axle',
#    'parent_id': 1,
#    'parent_name': 'Get the tools and supplies ready',
#    'is_leafnode': True,
#    'unique_id': 2333}},
#  'Clean and Lubricate the Chain': {'0': {'id': 0,
#    'is_leafnode': False,
#    'name': 'Clean and Lubricate the Chain',
#    'parent_id': None,
#    'parent_name': None},
#   '1': {'id': 1,
#    'is_leafnode': False,
#    'name': 'Degrease the chain',
#    'parent_id': 0,
#    'parent_name': 'Clean and Lubricate the Chain'},
#   '2': {'id': 2,
#    'is_leafnode': False,
#    'name': 'Prepare for cleaning',
#    'parent_id': 1,
#    'parent_name': 'Degrease the chain'},
#   '3': {'id': 3,
#    'is_leafnode': True,
#    'name': 'Get the brush',
#    'parent_id': 2,
#    'parent_name': 'Prepare for cleaning',
#    'unique_id': 957},
#   '4': {'id': 4,
#    'is_leafnode': True,
#    'name': 'Get the degreaser',
#    'parent_id': 2,
#    'parent_name': 'Prepare for cleaning',
#    'unique_id': 958},
#   '5': {'id': 5,
#    'is_leafnode': True,
#    'name': 'Get the cleaning tool',
#    'parent_id': 2,
#    'parent_name': 'Prepare for cleaning',
#    'unique_id': 959},
#   '6': {'id': 6,
#    'is_leafnode': True,
#    'name': 'Fill the cleaning tool with degreaser',
#    'parent_id': 2,
#    'parent_name': 'Prepare for cleaning',
#    'unique_id': 960},
#   '7': {'id': 7,
#    'is_leafnode': True,
#    'name': 'Add degreaser to the brush',
#    'parent_id': 2,
#    'parent_name': 'Prepare for cleaning',
#    'unique_id': 961},
#   '9': {'id': 9,
#    'is_leafnode': False,
#    'name': 'Clean the chain',
#    'parent_id': 1,
#    'parent_name': 'Degrease the chain'},
#   '10': {'id': 10,
#    'is_leafnode': True,
#    'name': 'Check the brake',
#    'parent_id': 9,
#    'parent_name': 'Clean the chain',
#    'unique_id': 948},
#   '11': {'id': 11,
#    'is_leafnode': True,
#    'name': 'Slowly move the chain by backpedaling with hand',
#    'parent_id': 9,
#    'parent_name': 'Clean the chain',
#    'unique_id': 964},
#   '12': {'id': 12,
#    'is_leafnode': True,
#    'name': 'Hold the brush to the chain as you backpedal with hand',
#    'parent_id': 9,
#    'parent_name': 'Clean the chain',
#    'unique_id': 965},
#   '14': {'id': 14,
#    'is_leafnode': True,
#    'name': 'Use a cloth to dry off any liquid on the chain',
#    'parent_id': 9,
#    'parent_name': 'Clean the chain',
#    'unique_id': 967},
#   '15': {'id': 15,
#    'is_leafnode': True,
#    'name': 'brush the chain while it remains stationary',
#    'parent_id': 9,
#    'parent_name': 'Clean the chain',
#    'unique_id': 968},
#   '16': {'id': 16,
#    'is_leafnode': False,
#    'name': 'Lubricate the chain',
#    'parent_id': 0,
#    'parent_name': 'Clean and Lubricate the Chain'},
#   '17': {'id': 17,
#    'is_leafnode': True,
#    'name': 'Get the chain lube',
#    'parent_id': 16,
#    'parent_name': 'Lubricate the chain',
#    'unique_id': 969},
#   '18': {'id': 18,
#    'is_leafnode': True,
#    'name': 'Get a cloth',
#    'parent_id': 16,
#    'parent_name': 'Lubricate the chain',
#    'unique_id': 970},
#   '19': {'id': 19,
#    'is_leafnode': True,
#    'name': 'Place a cloth underneath the chain to catch lube droppings',
#    'parent_id': 16,
#    'parent_name': 'Lubricate the chain',
#    'unique_id': 971},
#   '20': {'id': 20,
#    'is_leafnode': True,
#    'name': 'Slowly move the chain by backpedaling with hand, applying lube into the rollers, one by one',
#    'parent_id': 16,
#    'parent_name': 'Lubricate the chain',
#    'unique_id': 972},
#   '21': {'id': 21,
#    'is_leafnode': False,
#    'name': 'Clean up the tools',
#    'parent_id': 0,
#    'parent_name': 'Clean and Lubricate the Chain'},
#   '24': {'id': 24,
#    'is_leafnode': True,
#    'name': 'Clean the brush',
#    'parent_id': 21,
#    'parent_name': 'Clean up the tools',
#    'unique_id': 975},
#   '26': {'id': 26,
#    'name': 'Get the bicycle ready for cleaning',
#    'parent_id': 0,
#    'parent_name': 'Clean and Lubricate the Chain',
#    'is_leafnode': False},
#   '27': {'id': 27,
#    'name': 'Add degreaser to the chain',
#    'parent_id': 2,
#    'parent_name': 'Prepare for cleaning',
#    'is_leafnode': True,
#    'unique_id': 976},
#   '29': {'id': 29,
#    'name': 'Attach the bicycle to the steel pole',
#    'parent_id': 26,
#    'parent_name': 'Get the bicycle ready for cleaning',
#    'is_leafnode': True,
#    'unique_id': 978},
#   '30': {'id': 30,
#    'is_leafnode': True,
#    'name': 'Slowly move the chain by backpedaling with hand',
#    'parent_id': 2,
#    'parent_name': 'Prepare for cleaning',
#    'unique_id': 964},
#   '31': {'id': 31,
#    'is_leafnode': True,
#    'name': 'Use a cloth to dry off any liquid on the chain',
#    'parent_id': 16,
#    'parent_name': 'Lubricate the chain',
#    'unique_id': 967},
#   '32': {'id': 32,
#    'is_leafnode': True,
#    'name': 'Get a cloth',
#    'parent_id': 2,
#    'parent_name': 'Prepare for cleaning',
#    'unique_id': 970}},
#  'First Aid - CPR': {'0': {'id': 0,
#    'is_leafnode': False,
#    'name': 'First Aid - CPR',
#    'parent_id': None,
#    'parent_name': None},
#   '1': {'id': 1,
#    'is_leafnode': False,
#    'name': 'Check if the patient is conscious or unconscious',
#    'parent_id': 0,
#    'parent_name': 'First Aid - CPR'},
#   '2': {'id': 2,
#    'is_leafnode': True,
#    'name': 'Have a conversation asking different questions',
#    'parent_id': 1,
#    'parent_name': 'Check if the patient is conscious or unconscious',
#    'unique_id': 979},
#   '3': {'id': 3,
#    'is_leafnode': True,
#    'name': 'Confirm patient consciousness from the breath',
#    'parent_id': 1,
#    'parent_name': 'Check if the patient is conscious or unconscious',
#    'unique_id': 986},
#   '4': {'id': 4,
#    'is_leafnode': True,
#    'name': 'Check if the patient is responding at all',
#    'parent_id': 1,
#    'parent_name': 'Check if the patient is conscious or unconscious',
#    'unique_id': 981},
#   '5': {'id': 5,
#    'is_leafnode': True,
#    'name': 'Tap patient to confirm consciousness',
#    'parent_id': 1,
#    'parent_name': 'Check if the patient is conscious or unconscious',
#    'unique_id': 985},
#   '6': {'id': 6,
#    'is_leafnode': True,
#    'name': 'Check if the patient is responding at all',
#    'parent_id': 1,
#    'parent_name': 'Check if the patient is conscious or unconscious',
#    'unique_id': 981},
#   '8': {'id': 8,
#    'is_leafnode': True,
#    'name': 'Tap patient to confirm consciousness',
#    'parent_id': 1,
#    'parent_name': 'Check if the patient is conscious or unconscious',
#    'unique_id': 985},
#   '9': {'id': 9,
#    'is_leafnode': True,
#    'name': 'Confirm patient consciousness from the breath',
#    'parent_id': 1,
#    'parent_name': 'Check if the patient is conscious or unconscious',
#    'unique_id': 986},
#   '10': {'id': 10,
#    'is_leafnode': True,
#    'name': 'Check if the patient is responding at all',
#    'parent_id': 1,
#    'parent_name': 'Check if the patient is conscious or unconscious',
#    'unique_id': 981},
#   '11': {'id': 11,
#    'is_leafnode': False,
#    'name': 'Get ready to perform CPR',
#    'parent_id': 0,
#    'parent_name': 'First Aid - CPR'},
#   '13': {'id': 13,
#    'is_leafnode': True,
#    'name': "Kneel on the side of the patient's neck and shoulders",
#    'parent_id': 11,
#    'parent_name': 'Get ready to perform CPR',
#    'unique_id': 989},
#   '14': {'id': 14,
#    'is_leafnode': False,
#    'name': 'Perform CPR',
#    'parent_id': 0,
#    'parent_name': 'First Aid - CPR'},
#   '15': {'id': 15,
#    'is_leafnode': True,
#    'name': "Place the lower part of the palm (heel) on the center of the patient's chest",
#    'parent_id': 14,
#    'parent_name': 'Perform CPR',
#    'unique_id': 990},
#   '16': {'id': 16,
#    'is_leafnode': True,
#    'name': 'Place the other hand on top of the first',
#    'parent_id': 14,
#    'parent_name': 'Perform CPR',
#    'unique_id': 991},
#   '17': {'id': 17,
#    'is_leafnode': True,
#    'name': 'Press hard at a rate of 100 to 120 compressions per minute',
#    'parent_id': 14,
#    'parent_name': 'Perform CPR',
#    'unique_id': 993},
#   '18': {'id': 18,
#    'is_leafnode': True,
#    'name': 'Press hard at a rate of 100 to 120 compressions per minute',
#    'parent_id': 14,
#    'parent_name': 'Perform CPR',
#    'unique_id': 993},
#   '22': {'id': 22,
#    'is_leafnode': True,
#    'name': 'Do artificial respirations two times after 30 press',
#    'parent_id': 14,
#    'parent_name': 'Perform CPR',
#    'unique_id': 996},
#   '23': {'id': 23,
#    'is_leafnode': True,
#    'name': 'Call for help',
#    'parent_id': 0,
#    'parent_name': 'First Aid - CPR',
#    'unique_id': 997}},
#  'Making Coffee latte': {'0': {'id': 0,
#    'is_leafnode': False,
#    'name': 'Making Coffee latte',
#    'parent_id': None,
#    'parent_name': None},
#   '504': {'id': 504,
#    'is_leafnode': False,
#    'name': 'Get Ingredients',
#    'parent_id': 0,
#    'parent_name': 'Making Coffee latte'},
#   '519': {'id': 519,
#    'is_leafnode': True,
#    'name': 'Get chocolate',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 519},
#   '521': {'id': 521,
#    'is_leafnode': True,
#    'name': 'Get cinnamon powder',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 521},
#   '522': {'id': 522,
#    'is_leafnode': True,
#    'name': 'Get cinnamon stick',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 1915},
#   '524': {'id': 524,
#    'is_leafnode': True,
#    'name': 'Get coffee beans',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 524},
#   '525': {'id': 525,
#    'is_leafnode': True,
#    'name': 'Get coffee grounds',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 525},
#   '547': {'id': 547,
#    'is_leafnode': True,
#    'name': 'Get coffee grounds',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 525},
#   '558': {'id': 558,
#    'is_leafnode': True,
#    'name': 'Get milk',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 558},
#   '585': {'id': 585,
#    'is_leafnode': True,
#    'name': 'Get sugar',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 585},
#   '598': {'id': 598,
#    'is_leafnode': True,
#    'name': 'Get water',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 598},
#   '600': {'id': 600,
#    'is_leafnode': False,
#    'name': 'Get kitchenware & utensils',
#    'parent_id': 0,
#    'parent_name': 'Making Coffee latte'},
#   '601': {'id': 601,
#    'is_leafnode': True,
#    'name': 'Get a bowl',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 2181},
#   '603': {'id': 603,
#    'is_leafnode': True,
#    'name': 'Get chopping board',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 603},
#   '605': {'id': 605,
#    'is_leafnode': True,
#    'name': 'Get a cup or mug',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 638},
#   '606': {'id': 606,
#    'is_leafnode': True,
#    'name': 'Get coffee filter',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 606},
#   '608': {'id': 608,
#    'is_leafnode': True,
#    'name': 'Get a cup or mug',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 638},
#   '610': {'id': 610,
#    'is_leafnode': True,
#    'name': 'Get an electric kettle',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 1338},
#   '611': {'id': 611,
#    'is_leafnode': True,
#    'name': 'Get fork',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 611},
#   '616': {'id': 616,
#    'is_leafnode': True,
#    'name': 'Get kitchen towel',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 616},
#   '617': {'id': 617,
#    'is_leafnode': True,
#    'name': 'Get knife',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 617},
#   '619': {'id': 619,
#    'is_leafnode': True,
#    'name': 'Get measuring tool (scoop or spoon or cup)',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 619},
#   '620': {'id': 620,
#    'is_leafnode': True,
#    'name': 'Get napkin',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 620},
#   '622': {'id': 622,
#    'is_leafnode': True,
#    'name': 'Get pitcher',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 622},
#   '625': {'id': 625,
#    'is_leafnode': True,
#    'name': 'Get a pot or saucepan',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 1333},
#   '630': {'id': 630,
#    'is_leafnode': True,
#    'name': 'Get spoon',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 630},
#   '633': {'id': 633,
#    'is_leafnode': False,
#    'name': 'Clean up',
#    'parent_id': 0,
#    'parent_name': 'Making Coffee latte'},
#   '634': {'id': 634,
#    'is_leafnode': False,
#    'name': 'Wash kitchenware & utensils',
#    'parent_id': 633,
#    'parent_name': 'Clean up'},
#   '639': {'id': 639,
#    'is_leafnode': True,
#    'name': 'Wash cup or mug',
#    'parent_id': 634,
#    'parent_name': 'Wash kitchenware & utensils',
#    'unique_id': 662},
#   '642': {'id': 642,
#    'is_leafnode': True,
#    'name': 'Wash cup or mug',
#    'parent_id': 634,
#    'parent_name': 'Wash kitchenware & utensils',
#    'unique_id': 662},
#   '651': {'id': 651,
#    'is_leafnode': True,
#    'name': 'Wash knife',
#    'parent_id': 634,
#    'parent_name': 'Wash kitchenware & utensils',
#    'unique_id': 671},
#   '653': {'id': 653,
#    'is_leafnode': True,
#    'name': 'Wash measuring tool (scoop or spoon or cup)',
#    'parent_id': 634,
#    'parent_name': 'Wash kitchenware & utensils',
#    'unique_id': 673},
#   '654': {'id': 654,
#    'is_leafnode': True,
#    'name': 'Wash napkin',
#    'parent_id': 634,
#    'parent_name': 'Wash kitchenware & utensils',
#    'unique_id': 674},
#   '656': {'id': 656,
#    'is_leafnode': True,
#    'name': 'Wash pitcher',
#    'parent_id': 634,
#    'parent_name': 'Wash kitchenware & utensils',
#    'unique_id': 676},
#   '659': {'id': 659,
#    'is_leafnode': True,
#    'name': 'Wash pot or saucepan',
#    'parent_id': 634,
#    'parent_name': 'Wash kitchenware & utensils',
#    'unique_id': 679},
#   '660': {'id': 660,
#    'is_leafnode': True,
#    'name': 'Wash pour-over coffee maker or dripper',
#    'parent_id': 634,
#    'parent_name': 'Wash kitchenware & utensils',
#    'unique_id': 680},
#   '664': {'id': 664,
#    'is_leafnode': True,
#    'name': 'Wash spoon',
#    'parent_id': 634,
#    'parent_name': 'Wash kitchenware & utensils',
#    'unique_id': 684},
#   '667': {'id': 667,
#    'is_leafnode': False,
#    'name': 'Put away kitchenware & utensils',
#    'parent_id': 633,
#    'parent_name': 'Clean up'},
#   '668': {'id': 668,
#    'is_leafnode': True,
#    'name': 'Put away bowl',
#    'parent_id': 667,
#    'parent_name': 'Put away kitchenware & utensils',
#    'unique_id': 688},
#   '673': {'id': 673,
#    'is_leafnode': True,
#    'name': 'Put away coffee filter',
#    'parent_id': 667,
#    'parent_name': 'Put away kitchenware & utensils',
#    'unique_id': 693},
#   '675': {'id': 675,
#    'is_leafnode': True,
#    'name': 'Put away cup or mug',
#    'parent_id': 667,
#    'parent_name': 'Put away kitchenware & utensils',
#    'unique_id': 695},
#   '687': {'id': 687,
#    'is_leafnode': True,
#    'name': 'Put away napkin',
#    'parent_id': 667,
#    'parent_name': 'Put away kitchenware & utensils',
#    'unique_id': 707},
#   '689': {'id': 689,
#    'is_leafnode': True,
#    'name': 'Put away pitcher',
#    'parent_id': 667,
#    'parent_name': 'Put away kitchenware & utensils',
#    'unique_id': 709},
#   '692': {'id': 692,
#    'is_leafnode': True,
#    'name': 'Put away pot or saucepan',
#    'parent_id': 667,
#    'parent_name': 'Put away kitchenware & utensils',
#    'unique_id': 712},
#   '693': {'id': 693,
#    'is_leafnode': True,
#    'name': 'Put away pour-over coffee maker or dripper',
#    'parent_id': 667,
#    'parent_name': 'Put away kitchenware & utensils',
#    'unique_id': 713},
#   '697': {'id': 697,
#    'is_leafnode': True,
# ...
#    'unique_id': 493},
#   '1133': {'id': 1133,
#    'is_leafnode': True,
#    'name': 'Turn on the stove',
#    'parent_id': 833,
#    'parent_name': 'Boil noodles in boiling water',
#    'unique_id': 491},
#   '1134': {'id': 1134,
#    'is_leafnode': True,
#    'name': 'Lift the lid of a skillet or pan or pot',
#    'parent_id': 865,
#    'parent_name': 'Stir fry ingredients',
#    'unique_id': 494},
#   '1135': {'id': 1135,
#    'is_leafnode': True,
#    'name': 'Adjust the stove heat',
#    'parent_id': 865,
#    'parent_name': 'Stir fry ingredients',
#    'unique_id': 492},
#   '1136': {'id': 1136,
#    'is_leafnode': True,
#    'name': 'Visually inspect the recipe',
#    'parent_id': 846,
#    'parent_name': 'Boil the noodles until tender',
#    'unique_id': 489},
#   '1137': {'id': 1137,
#    'is_leafnode': True,
#    'name': 'Turn on the stove',
#    'parent_id': 836,
#    'parent_name': 'Heat the pot over medium heat',
#    'unique_id': 491},
#   '1138': {'id': 1138,
#    'is_leafnode': True,
#    'name': 'Turn on the stove',
#    'parent_id': 855,
#    'parent_name': 'Prepare a skillet',
#    'unique_id': 491},
#   '1139': {'id': 1139,
#    'is_leafnode': True,
#    'name': 'Wash hands',
#    'parent_id': 633,
#    'parent_name': 'Serve',
#    'unique_id': 3},
#   '1140': {'id': 1140,
#    'is_leafnode': True,
#    'name': 'Taste the recipe',
#    'parent_id': 865,
#    'parent_name': 'Stir fry ingredients',
#    'unique_id': 486},
#   '1141': {'id': 1141,
#    'is_leafnode': True,
#    'name': 'Visually inspect the recipe',
#    'parent_id': 865,
#    'parent_name': 'Stir fry ingredients',
#    'unique_id': 489},
#   '1142': {'id': 1142,
#    'is_leafnode': True,
#    'name': 'Peel fresh ginger',
#    'parent_id': 0,
#    'parent_name': 'Cooking Noodles',
#    'unique_id': 237},
#   '1143': {'id': 1143,
#    'is_leafnode': True,
#    'name': 'Cut ginger',
#    'parent_id': 0,
#    'parent_name': 'Cooking Noodles',
#    'unique_id': 1909},
#   '1144': {'id': 1144,
#    'is_leafnode': True,
#    'name': 'Cut celeries',
#    'parent_id': 0,
#    'parent_name': 'Cooking Noodles',
#    'unique_id': 304},
#   '1145': {'id': 1145,
#    'is_leafnode': True,
#    'name': 'Wash noodles',
#    'parent_id': 0,
#    'parent_name': 'Cooking Noodles',
#    'unique_id': 159},
#   '1146': {'id': 1146,
#    'is_leafnode': True,
#    'name': 'Cut mustard leaves',
#    'parent_id': 0,
#    'parent_name': 'Cooking Noodles',
#    'unique_id': 350},
#   '1147': {'id': 1147,
#    'is_leafnode': True,
#    'name': 'Cut cabbage',
#    'parent_id': 0,
#    'parent_name': 'Cooking Noodles',
#    'unique_id': 301},
#   '1148': {'id': 1148,
#    'is_leafnode': True,
#    'name': 'Peel spring onions',
#    'parent_id': 0,
#    'parent_name': 'Cooking Noodles',
#    'unique_id': 278},
#   '1149': {'id': 1149,
#    'is_leafnode': True,
#    'name': 'Wash garlic cloves',
#    'parent_id': 0,
#    'parent_name': 'Cooking Noodles',
#    'unique_id': 138},
#   '1150': {'id': 1150,
#    'is_leafnode': True,
#    'name': 'Peel onions',
#    'parent_id': 0,
#    'parent_name': 'Cooking Noodles',
#    'unique_id': 260},
#   '1151': {'id': 1151,
#    'is_leafnode': True,
#    'name': 'Cut onions',
#    'parent_id': 0,
#    'parent_name': 'Cooking Noodles',
#    'unique_id': 356},
#   '1152': {'id': 1152,
#    'is_leafnode': True,
#    'name': 'Add dried herbs',
#    'parent_id': 0,
#    'parent_name': 'Cooking Noodles',
#    'unique_id': 31},
#   '1153': {'id': 1153,
#    'is_leafnode': True,
#    'name': 'Cut scallion',
#    'parent_id': 0,
#    'parent_name': 'Cooking Noodles',
#    'unique_id': 368},
#   '1154': {'id': 1154,
#    'is_leafnode': True,
#    'name': 'Wash scallion',
#    'parent_id': 0,
#    'parent_name': 'Cooking Noodles',
#    'unique_id': 176},
#   '1155': {'id': 1155,
#    'is_leafnode': True,
#    'name': 'Cut noodles',
#    'parent_id': 0,
#    'parent_name': 'Cooking Noodles',
#    'unique_id': 351},
#   '1156': {'id': 1156,
#    'is_leafnode': True,
#    'name': 'Cut chili powder',
#    'parent_id': 0,
#    'parent_name': 'Cooking Noodles',
#    'unique_id': 308},
#   '1157': {'id': 1157,
#    'is_leafnode': True,
#    'name': 'Cut garlic powder',
#    'parent_id': 0,
#    'parent_name': 'Cooking Noodles',
#    'unique_id': 332}},
#  'Cooking Sushi Rolls': {'0': {'id': 0,
#    'is_leafnode': False,
#    'name': 'Cooking Sushi Rolls',
#    'parent_id': None,
#    'parent_name': None},
#   '504': {'id': 504,
#    'is_leafnode': False,
#    'name': 'Get Ingredients',
#    'parent_id': 0,
#    'parent_name': 'Cooking Sushi Rolls'},
#   '573': {'id': 573,
#    'is_leafnode': True,
#    'name': 'Get raw fish',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 573},
#   '586': {'id': 586,
#    'is_leafnode': True,
#    'name': 'Get tamari',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 586},
#   '600': {'id': 600,
#    'is_leafnode': False,
#    'name': 'Get kitchenware & utensils',
#    'parent_id': 0,
#    'parent_name': 'Cooking Sushi Rolls'},
#   '604': {'id': 604,
#    'is_leafnode': True,
#    'name': 'Get chopsticks',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 604},
#   '611': {'id': 611,
#    'is_leafnode': True,
#    'name': 'Get fork',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 611},
#   '623': {'id': 623,
#    'is_leafnode': True,
#    'name': 'Get plate',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 623},
#   '630': {'id': 630,
#    'is_leafnode': True,
#    'name': 'Get spoon',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 630},
#   '633': {'id': 633,
#    'is_leafnode': False,
#    'name': 'Serve',
#    'parent_id': 0,
#    'parent_name': 'Cooking Sushi Rolls'},
#   '634': {'id': 634,
#    'is_leafnode': True,
#    'name': 'Transfer food to a plate',
#    'parent_id': 633,
#    'parent_name': 'Serve',
#    'unique_id': 634},
#   '653': {'id': 653,
#    'is_leafnode': False,
#    'name': 'Clean up',
#    'parent_id': 0,
#    'parent_name': 'Cooking Sushi Rolls'},
#   '654': {'id': 654,
#    'is_leafnode': False,
#    'name': 'Wash kitchenware & utensils',
#    'parent_id': 653,
#    'parent_name': 'Clean up'},
#   '677': {'id': 677,
#    'is_leafnode': True,
#    'name': 'Wash plate',
#    'parent_id': 654,
#    'parent_name': 'Wash kitchenware & utensils',
#    'unique_id': 677},
#   '818': {'id': 818,
#    'is_leafnode': False,
#    'name': 'Cook rice',
#    'parent_id': 0,
#    'parent_name': 'Cooking Sushi Rolls'},
#   '821': {'id': 821,
#    'is_leafnode': False,
#    'name': 'Cook rice using a rice cooker',
#    'parent_id': 818,
#    'parent_name': 'Cook rice'},
#   '824': {'id': 824,
#    'is_leafnode': True,
#    'name': 'Turn on the electric rice cooker',
#    'parent_id': 821,
#    'parent_name': 'Cook rice using a rice cooker',
#    'unique_id': 2154},
#   '835': {'id': 835,
#    'is_leafnode': False,
#    'name': 'Make sushi roll',
#    'parent_id': 0,
#    'parent_name': 'Cooking Sushi Rolls'},
#   '846': {'id': 846,
#    'is_leafnode': False,
#    'name': 'Mix ingredients',
#    'parent_id': 835,
#    'parent_name': 'Make sushi roll'},
#   '847': {'id': 847,
#    'is_leafnode': True,
#    'name': 'Add sushi seasoning mixture to the cooked rice',
#    'parent_id': 846,
#    'parent_name': 'Mix ingredients',
#    'unique_id': 2171},
#   '848': {'id': 848,
#    'is_leafnode': True,
#    'name': 'Place a sheet of dried seaweed on your rolling mat',
#    'parent_id': 846,
#    'parent_name': 'Mix ingredients',
#    'unique_id': 2172},
#   '850': {'id': 850,
#    'is_leafnode': True,
#    'name': 'Spread a thin layer of sushi rice onto the sheet of nori',
#    'parent_id': 846,
#    'parent_name': 'Mix ingredients',
#    'unique_id': 2174},
#   '854': {'id': 854,
#    'is_leafnode': False,
#    'name': 'Rolling and Cutting Your Sushi',
#    'parent_id': 835,
#    'parent_name': 'Make sushi roll'},
#   '855': {'id': 855,
#    'is_leafnode': True,
#    'name': 'Roll the sushi up from the bottom using your mat',
#    'parent_id': 854,
#    'parent_name': 'Rolling and Cutting Your Sushi',
#    'unique_id': 2177},
#   '856': {'id': 856,
#    'is_leafnode': True,
#    'name': 'Wet a sharp knife with cool water.',
#    'parent_id': 854,
#    'parent_name': 'Rolling and Cutting Your Sushi',
#    'unique_id': 2178},
#   '857': {'id': 857,
#    'is_leafnode': True,
#    'name': 'Cut the sushi roll into pieces',
#    'parent_id': 854,
#    'parent_name': 'Rolling and Cutting Your Sushi',
#    'unique_id': 2179},
#   '859': {'id': 859,
#    'is_leafnode': True,
#    'name': 'Add raw fish',
#    'parent_id': 846,
#    'parent_name': 'Mix ingredients',
#    'unique_id': 74},
#   '860': {'id': 860,
#    'is_leafnode': True,
#    'name': 'Add tamari',
#    'parent_id': 846,
#    'parent_name': 'Mix ingredients',
#    'unique_id': 87},
#   '861': {'id': 861,
#    'is_leafnode': True,
#    'name': 'Check phone',
#    'parent_id': 835,
#    'parent_name': 'Make sushi roll',
#    'unique_id': 499},
#   '862': {'id': 862,
#    'is_leafnode': True,
#    'name': 'Add vinegar',
#    'parent_id': 846,
#    'parent_name': 'Mix ingredients',
#    'unique_id': 98},
#   '863': {'id': 863,
#    'is_leafnode': True,
#    'name': 'Wash hands',
#    'parent_id': 653,
#    'parent_name': 'Clean up',
#    'unique_id': 3}},
#  'Cooking Pasta': {'0': {'id': 0,
#    'is_leafnode': False,
#    'name': 'Cooking Pasta',
#    'parent_id': None,
#    'parent_name': None},
#   '504': {'id': 504,
#    'is_leafnode': False,
#    'name': 'Get Ingredients',
#    'parent_id': 0,
#    'parent_name': 'Cooking Pasta'},
#   '532': {'id': 532,
#    'is_leafnode': True,
#    'name': 'Get eggs',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 532},
#   '534': {'id': 534,
#    'is_leafnode': True,
#    'name': 'Get flour',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 534},
#   '600': {'id': 600,
#    'is_leafnode': False,
#    'name': 'Get kitchenware & utensils',
#    'parent_id': 0,
#    'parent_name': 'Cooking Pasta'},
#   '617': {'id': 617,
#    'is_leafnode': True,
#    'name': 'Get knife',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 617},
#   '630': {'id': 630,
#    'is_leafnode': True,
#    'name': 'Get spoon',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 630},
#   '653': {'id': 653,
#    'is_leafnode': False,
#    'name': 'Clean up',
#    'parent_id': 0,
#    'parent_name': 'Cooking Pasta'},
#   '720': {'id': 720,
#    'is_leafnode': False,
#    'name': 'Put away ingredients',
#    'parent_id': 653,
#    'parent_name': 'Clean up'},
#   '748': {'id': 748,
#    'is_leafnode': True,
#    'name': 'Put away eggs',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 748},
#   '750': {'id': 750,
#    'is_leafnode': True,
#    'name': 'Put away flour',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 750},
#   '817': {'id': 817,
#    'is_leafnode': True,
#    'name': 'Throw out trash or waste',
#    'parent_id': 653,
#    'parent_name': 'Clean up',
#    'unique_id': 817},
#   '820': {'id': 820,
#    'is_leafnode': False,
#    'name': 'Make dough',
#    'parent_id': 0,
#    'parent_name': 'Cooking Pasta'},
#   '821': {'id': 821,
#    'is_leafnode': False,
#    'name': 'Prepare wet ingredients',
#    'parent_id': 820,
#    'parent_name': 'Make dough'},
#   '823': {'id': 823,
#    'is_leafnode': True,
#    'name': 'Crack eggs into a mixing bowl',
#    'parent_id': 821,
#    'parent_name': 'Prepare wet ingredients',
#    'unique_id': 1110},
#   '824': {'id': 824,
#    'is_leafnode': True,
#    'name': 'Add water',
#    'parent_id': 821,
#    'parent_name': 'Prepare wet ingredients',
#    'unique_id': 99},
#   '826': {'id': 826,
#    'is_leafnode': False,
#    'name': 'Prepare dry ingredients',
#    'parent_id': 820,
#    'parent_name': 'Make dough'},
#   '827': {'id': 827,
#    'is_leafnode': True,
#    'name': 'Measure out flour',
#    'parent_id': 826,
#    'parent_name': 'Prepare dry ingredients',
#    'unique_id': 2185},
#   '830': {'id': 830,
#    'is_leafnode': True,
#    'name': 'Toss or mix flour mixture',
#    'parent_id': 826,
#    'parent_name': 'Prepare dry ingredients',
#    'unique_id': 2188},
#   '834': {'id': 834,
#    'is_leafnode': False,
#    'name': 'Make pasta',
#    'parent_id': 0,
#    'parent_name': 'Cooking Pasta'},
#   '835': {'id': 835,
#    'is_leafnode': False,
#    'name': 'Make dough ball',
#    'parent_id': 834,
#    'parent_name': 'Make pasta'},
#   '836': {'id': 836,
#    'is_leafnode': True,
#    'name': 'Knead dough',
#    'parent_id': 835,
#    'parent_name': 'Make dough ball',
#    'unique_id': 2191},
#   '837': {'id': 837,
#    'is_leafnode': True,
#    'name': 'Roll dough into ball',
#    'parent_id': 835,
#    'parent_name': 'Make dough ball',
#    'unique_id': 2192},
#   '839': {'id': 839,
#    'is_leafnode': False,
#    'name': 'Prepare surface for rolling',
#    'parent_id': 834,
#    'parent_name': 'Make pasta'},
#   '840': {'id': 840,
#    'is_leafnode': True,
#    'name': 'Add flour to surface',
#    'parent_id': 839,
#    'parent_name': 'Prepare surface for rolling',
#    'unique_id': 2194},
#   '841': {'id': 841,
#    'is_leafnode': False,
#    'name': 'Roll and cut pasta',
#    'parent_id': 834,
#    'parent_name': 'Make pasta'},
#   '842': {'id': 842,
#    'is_leafnode': True,
#    'name': 'Roll out dough with rolling pin or utensil',
#    'parent_id': 841,
#    'parent_name': 'Roll and cut pasta',
#    'unique_id': 2195},
#   '843': {'id': 843,
#    'is_leafnode': True,
#    'name': 'Flatten dough with pasta machine',
#    'parent_id': 841,
#    'parent_name': 'Roll and cut pasta',
#    'unique_id': 2196},
#   '844': {'id': 844,
#    'is_leafnode': True,
#    'name': 'Use knife (or pasta machine) to cut pasta',
#    'parent_id': 841,
#    'parent_name': 'Roll and cut pasta',
#    'unique_id': 2197},
#   '846': {'id': 846,
#    'is_leafnode': True,
#    'name': 'Wash hands',
#    'parent_id': 653,
#    'parent_name': 'Clean up',
#    'unique_id': 3},
#   '847': {'id': 847,
#    'is_leafnode': True,
#    'name': 'Wipe hands',
#    'parent_id': 653,
#    'parent_name': 'Clean up',
#    'unique_id': 4},
#   '848': {'id': 848,
#    'is_leafnode': True,
#    'name': 'Get a bowl',
#    'parent_id': 841,
#    'parent_name': 'Roll and cut pasta',
#    'unique_id': 2181},
#   '849': {'id': 849,
#    'name': 'Combine wet and dry ingredients',
#    'parent_id': 820,
#    'parent_name': 'Make dough',
#    'is_leafnode': False,
#    'unique_id': None},
#   '850': {'id': 850,
#    'name': 'Create hole in flour',
#    'parent_id': 849,
#    'parent_name': 'Combine wet and dry ingredients',
#    'is_leafnode': True,
#    'unique_id': 2324},
#   '851': {'id': 851,
#    'name': 'Add salt',
#    'parent_id': 826,
#    'parent_name': 'Prepare dry ingredients',
#    'is_leafnode': True,
#    'unique_id': 78},
#   '852': {'id': 852,
#    'name': 'Get salt',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'is_leafnode': True,
#    'unique_id': 577},
#   '853': {'id': 853,
#    'name': 'Get measuring tool (scoop or spoon or cup)',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'is_leafnode': True,
#    'unique_id': 619},
#   '854': {'id': 854,
#    'name': 'Check the recipe instruction',
#    'parent_id': 826,
#    'parent_name': 'Prepare dry ingredients',
#    'is_leafnode': True,
#    'unique_id': 2325},
#   '855': {'id': 855,
#    'name': 'Get rolling pin',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'is_leafnode': True,
#    'unique_id': 2326},
#   '856': {'id': 856,
#    'name': 'Get measuring cup',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'is_leafnode': True,
#    'unique_id': 2327},
#   '857': {'id': 857,
#    'name': 'Pour flour into mixing bowl',
#    'parent_id': 826,
#    'parent_name': 'Prepare dry ingredients',
#    'is_leafnode': True,
#    'unique_id': 2328},
#   '858': {'id': 858,
#    'name': 'Whisk egg',
#    'parent_id': 821,
#    'parent_name': 'Prepare wet ingredients',
#    'is_leafnode': True,
#    'unique_id': 2329},
#   '859': {'id': 859,
#    'name': 'Add beaten egg into hole',
#    'parent_id': 849,
#    'parent_name': 'Combine wet and dry ingredients',
#    'is_leafnode': True,
#    'unique_id': 2330},
#   '860': {'id': 860,
#    'name': 'Mix egg and flour together',
#    'parent_id': 849,
#    'parent_name': 'Combine wet and dry ingredients',
#    'is_leafnode': True,
#    'unique_id': 2331},
#   '861': {'id': 861,
#    'name': 'Mix water with egg and flour in a bowl',
#    'parent_id': 849,
#    'parent_name': 'Combine wet and dry ingredients',
#    'is_leafnode': True,
#    'unique_id': 2332}}}

# %% [markdown]
# # Get video uids for cooking videos with narration annotations
# - Get video uids to download from CLI EGoExo downloader

# %%
# only get videos with keystep annotations
cooking_uids = []
for item in takes:
    # check if this take is cooking
    cat = item['parent_task_id']
    if cat != 1000:
        continue

    # check if this take has annotations
    has_annotations = False
    for check_if_annotated in anns.keys():
        if anns[check_if_annotated]['take_uid'] == item['take_uid']:
            has_annotations = True
            break
    if not has_annotations:
        continue
    
    cooking_uids.append(item['take_uid'])

print(len(cooking_uids))

# with open('egoexo4d/all_cooking_videos.txt', mode='wt', encoding='utf-8') as myfile:
#     myfile.write('\n'.join(cooking_uids))
# Out:
# 344

# %%
cooking_annotations = {}
for uid in cooking_uids:
    cooking_annotations[uid] = keystep_anns['annotations'][uid]

# collect all cooking scenarios  
cooking_scenarios = set()
for uid in cooking_annotations.keys():
    cooking_scenarios.add(cooking_annotations[uid]['scenario'])

cooking_scenarios = list(cooking_scenarios)
cooking_scenarios
# Out:
# ['Making Sesame-Ginger Asian Salad',
#  'Cooking Noodles',
#  'Cooking Scrambled Eggs',
#  'Cooking Pasta',
#  'Making Coffee latte',
#  'Cooking an Omelet',
#  'Making Chai Tea',
#  'Making Cucumber & Tomato Salad',
#  'Cooking Tomato & Eggs',
#  'Cooking Sushi Rolls',
#  'Making Milk Tea']

# %%
# filter cooking scenarios
taxonomy_cooking = {}
for scenario in cooking_scenarios:
    taxonomy_cooking[scenario] = keystep_anns['taxonomy'][scenario] 

taxonomy_cooking
# Out:
# {'Making Sesame-Ginger Asian Salad': {'0': {'id': 0,
#    'is_leafnode': False,
#    'name': 'Making Sesame-Ginger Asian Salad',
#    'parent_id': None,
#    'parent_name': None},
#   '504': {'id': 504,
#    'is_leafnode': False,
#    'name': 'Get Ingredients',
#    'parent_id': 0,
#    'parent_name': 'Making Sesame-Ginger Asian Salad'},
#   '506': {'id': 506,
#    'is_leafnode': True,
#    'name': 'Get almonds',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 506},
#   '508': {'id': 508,
#    'is_leafnode': True,
#    'name': 'Get bell peppers',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 508},
#   '512': {'id': 512,
#    'is_leafnode': True,
#    'name': 'Get cardamom',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 512},
#   '513': {'id': 513,
#    'is_leafnode': True,
#    'name': 'Get carrots',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 513},
#   '514': {'id': 514,
#    'is_leafnode': True,
#    'name': 'Get celeries',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 514},
#   '517': {'id': 517,
#    'is_leafnode': True,
#    'name': 'Get cherry tomatoes',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 517},
#   '518': {'id': 518,
#    'is_leafnode': True,
#    'name': 'Get chili powder',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 518},
#   '520': {'id': 520,
#    'is_leafnode': True,
#    'name': 'Get cilantro',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 520},
#   '521': {'id': 521,
#    'is_leafnode': True,
#    'name': 'Get cinnamon powder',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 521},
#   '526': {'id': 526,
#    'is_leafnode': True,
#    'name': 'Get cilantro',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 520},
#   '527': {'id': 527,
#    'is_leafnode': True,
#    'name': 'Get cucumber',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 527},
#   '533': {'id': 533,
#    'is_leafnode': True,
#    'name': 'Get feta cheese',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 533},
#   '536': {'id': 536,
#    'is_leafnode': True,
#    'name': 'Get cilantro',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 520},
#   '540': {'id': 540,
#    'is_leafnode': True,
#    'name': 'Get garlic cloves',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 540},
#   '541': {'id': 541,
#    'is_leafnode': True,
#    'name': 'Get garlic paste',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 541},
#   '542': {'id': 542,
#    'is_leafnode': True,
#    'name': 'Get garlic powder',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 542},
#   '543': {'id': 543,
#    'is_leafnode': True,
#    'name': 'Get ginger',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 1907},
#   '546': {'id': 546,
#    'is_leafnode': True,
#    'name': 'Get green chilies',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 546},
#   '548': {'id': 548,
#    'is_leafnode': True,
#    'name': 'Get honey',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 548},
#   '552': {'id': 552,
#    'is_leafnode': True,
#    'name': 'Get lemon',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 552},
#   '553': {'id': 553,
#    'is_leafnode': True,
#    'name': 'Get lemon juice',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 553},
#   '554': {'id': 554,
#    'is_leafnode': True,
#    'name': 'Get lettuce',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 554},
#   '556': {'id': 556,
#    'is_leafnode': True,
#    'name': 'Get lime juice',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 556},
#   '557': {'id': 557,
#    'is_leafnode': True,
#    'name': 'Get mayonnaise',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 557},
#   '559': {'id': 559,
#    'is_leafnode': True,
#    'name': 'Get mustard',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 559},
#   '563': {'id': 563,
#    'is_leafnode': True,
#    'name': 'Get oil',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 563},
#   '564': {'id': 564,
#    'is_leafnode': True,
#    'name': 'Get olive oil',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 564},
#   '566': {'id': 566,
#    'is_leafnode': True,
#    'name': 'Get onions',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 566},
#   '568': {'id': 568,
#    'is_leafnode': True,
#    'name': 'Get oyster sauce',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 568},
#   '569': {'id': 569,
#    'is_leafnode': True,
#    'name': 'Get parsley',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 569},
#   '570': {'id': 570,
#    'is_leafnode': True,
#    'name': 'Get peanut butter',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 570},
#   '571': {'id': 571,
#    'is_leafnode': True,
#    'name': 'Get pepper',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 571},
#   '576': {'id': 576,
#    'is_leafnode': True,
#    'name': 'Get rice vinegar',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 576},
#   '577': {'id': 577,
#    'is_leafnode': True,
#    'name': 'Get salt',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 577},
#   '578': {'id': 578,
#    'is_leafnode': True,
#    'name': 'Get scallion',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 578},
#   '580': {'id': 580,
#    'is_leafnode': True,
#    'name': 'Get sesame oil',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 580},
#   '581': {'id': 581,
#    'is_leafnode': True,
#    'name': 'Get sesame seeds',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 581},
#   '582': {'id': 582,
#    'is_leafnode': True,
#    'name': 'Get soy sauce',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 582},
#   '583': {'id': 583,
#    'is_leafnode': True,
#    'name': 'Get spinach',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 583},
#   '584': {'id': 584,
#    'is_leafnode': True,
#    'name': 'Get spring onions',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 584},
#   '585': {'id': 585,
#    'is_leafnode': True,
#    'name': 'Get sugar',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 585},
#   '586': {'id': 586,
#    'is_leafnode': True,
#    'name': 'Get tamari',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 586},
#   '591': {'id': 591,
#    'is_leafnode': True,
#    'name': 'Get toasted sesame oil',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 591},
#   '595': {'id': 595,
#    'is_leafnode': True,
#    'name': 'Get tomato',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 592},
#   '599': {'id': 599,
#    'is_leafnode': True,
#    'name': 'Get white pepper',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 599},
#   '600': {'id': 600,
#    'is_leafnode': False,
#    'name': 'Get kitchenware & utensils',
#    'parent_id': 0,
#    'parent_name': 'Making Sesame-Ginger Asian Salad'},
#   '601': {'id': 601,
#    'is_leafnode': True,
#    'name': 'Get a bowl',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 2181},
#   '603': {'id': 603,
#    'is_leafnode': True,
#    'name': 'Get chopping board',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 603},
#   '604': {'id': 604,
#    'is_leafnode': True,
#    'name': 'Get chopsticks',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 604},
#   '608': {'id': 608,
#    'is_leafnode': True,
#    'name': 'Get a cup or mug',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 638},
#   '609': {'id': 609,
#    'is_leafnode': True,
#    'name': 'Get cutting board',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 609},
#   '611': {'id': 611,
#    'is_leafnode': True,
#    'name': 'Get fork',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 611},
#   '615': {'id': 615,
#    'is_leafnode': True,
#    'name': 'Get kitchen tong',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 615},
#   '616': {'id': 616,
#    'is_leafnode': True,
#    'name': 'Get kitchen towel',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 616},
#   '617': {'id': 617,
#    'is_leafnode': True,
#    'name': 'Get knife',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 617},
#   '618': {'id': 618,
#    'is_leafnode': True,
#    'name': 'Get ladle',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 618},
#   '619': {'id': 619,
#    'is_leafnode': True,
#    'name': 'Get measuring tool (scoop or spoon or cup)',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 619},
#   '620': {'id': 620,
#    'is_leafnode': True,
#    'name': 'Get napkin',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 620},
#   '621': {'id': 621,
#    'is_leafnode': True,
#    'name': 'Get peeler',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 621},
#   '622': {'id': 622,
#    'is_leafnode': True,
#    'name': 'Get pitcher',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 622},
#   '623': {'id': 623,
#    'is_leafnode': True,
#    'name': 'Get plate',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 623},
#   '628': {'id': 628,
#    'is_leafnode': True,
#    'name': 'Get skillet or frying pan or wok',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 628},
#   '630': {'id': 630,
#    'is_leafnode': True,
#    'name': 'Get spoon',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 630},
#   '633': {'id': 633,
#    'is_leafnode': False,
#    'name': 'Serve',
#    'parent_id': 0,
#    'parent_name': 'Making Sesame-Ginger Asian Salad'},
#   '634': {'id': 634,
#    'is_leafnode': True,
#    'name': 'Transfer food to a plate',
#    'parent_id': 633,
#    'parent_name': 'Serve',
#    'unique_id': 634},
#   '635': {'id': 635,
#    'is_leafnode': True,
#    'name': 'Transfer food to a plate',
#    'parent_id': 633,
#    'parent_name': 'Serve',
#    'unique_id': 634},
#   '653': {'id': 653,
#    'is_leafnode': False,
#    'name': 'Clean up',
#    'parent_id': 0,
#    'parent_name': 'Making Sesame-Ginger Asian Salad'},
#   '654': {'id': 654,
#    'is_leafnode': False,
#    'name': 'Wash kitchenware & utensils',
#    'parent_id': 653,
#    'parent_name': 'Clean up'},
#   '655': {'id': 655,
#    'is_leafnode': True,
#    'name': 'Wash bowl',
#    'parent_id': 654,
#    'parent_name': 'Wash kitchenware & utensils',
#    'unique_id': 655},
#   '657': {'id': 657,
#    'is_leafnode': True,
#    'name': 'Wash cutting board',
#    'parent_id': 654,
#    'parent_name': 'Wash kitchenware & utensils',
#    'unique_id': 663},
#   '663': {'id': 663,
#    'is_leafnode': True,
#    'name': 'Wash cutting board',
#    'parent_id': 654,
#    'parent_name': 'Wash kitchenware & utensils',
#    'unique_id': 663},
#   '665': {'id': 665,
#    'is_leafnode': True,
#    'name': 'Wash fork',
#    'parent_id': 654,
#    'parent_name': 'Wash kitchenware & utensils',
#    'unique_id': 665},
#   '671': {'id': 671,
#    'is_leafnode': True,
#    'name': 'Wash knife',
#    'parent_id': 654,
#    'parent_name': 'Wash kitchenware & utensils',
#    'unique_id': 671},
#   '673': {'id': 673,
#    'is_leafnode': True,
#    'name': 'Wash measuring tool (scoop or spoon or cup)',
#    'parent_id': 654,
#    'parent_name': 'Wash kitchenware & utensils',
#    'unique_id': 673},
#   '675': {'id': 675,
#    'is_leafnode': True,
#    'name': 'Wash peeler',
#    'parent_id': 654,
#    'parent_name': 'Wash kitchenware & utensils',
#    'unique_id': 675},
#   '676': {'id': 676,
#    'is_leafnode': True,
#    'name': 'Wash pitcher',
#    'parent_id': 654,
#    'parent_name': 'Wash kitchenware & utensils',
#    'unique_id': 676},
#   '677': {'id': 677,
#    'is_leafnode': True,
#    'name': 'Wash plate',
#    'parent_id': 654,
#    'parent_name': 'Wash kitchenware & utensils',
#    'unique_id': 677},
#   '683': {'id': 683,
#    'is_leafnode': True,
#    'name': 'Wash spatula',
#    'parent_id': 654,
#    'parent_name': 'Wash kitchenware & utensils',
#    'unique_id': 683},
#   '684': {'id': 684,
#    'is_leafnode': True,
#    'name': 'Wash spoon',
#    'parent_id': 654,
#    'parent_name': 'Wash kitchenware & utensils',
#    'unique_id': 684},
#   '687': {'id': 687,
#    'is_leafnode': False,
#    'name': 'Put away kitchenware & utensils',
#    'parent_id': 653,
#    'parent_name': 'Clean up'},
#   '688': {'id': 688,
#    'is_leafnode': True,
#    'name': 'Put away bowl',
#    'parent_id': 687,
#    'parent_name': 'Put away kitchenware & utensils',
#    'unique_id': 688},
#   '690': {'id': 690,
#    'is_leafnode': True,
#    'name': 'Put away chopping board',
#    'parent_id': 687,
#    'parent_name': 'Put away kitchenware & utensils',
#    'unique_id': 690},
#   '691': {'id': 691,
#    'is_leafnode': True,
#    'name': 'Put away chopsticks',
#    'parent_id': 687,
#    'parent_name': 'Put away kitchenware & utensils',
#    'unique_id': 691},
#   '704': {'id': 704,
#    'is_leafnode': True,
#    'name': 'Put away knife',
#    'parent_id': 687,
#    'parent_name': 'Put away kitchenware & utensils',
#    'unique_id': 704},
#   '706': {'id': 706,
#    'is_leafnode': True,
#    'name': 'Put away measuring tool (scoop or spoon or cup)',
#    'parent_id': 687,
#    'parent_name': 'Put away kitchenware & utensils',
#    'unique_id': 706},
#   '707': {'id': 707,
#    'is_leafnode': True,
#    'name': 'Put away napkin',
#    'parent_id': 687,
#    'parent_name': 'Put away kitchenware & utensils',
#    'unique_id': 707},
#   '710': {'id': 710,
#    'is_leafnode': True,
#    'name': 'Put away plate',
#    'parent_id': 687,
#    'parent_name': 'Put away kitchenware & utensils',
#    'unique_id': 710},
#   '716': {'id': 716,
#    'is_leafnode': True,
#    'name': 'Put away spatula',
#    'parent_id': 687,
#    'parent_name': 'Put away kitchenware & utensils',
#    'unique_id': 716},
#   '717': {'id': 717,
#    'is_leafnode': True,
#    'name': 'Put away spoon',
#    'parent_id': 687,
#    'parent_name': 'Put away kitchenware & utensils',
#    'unique_id': 717},
#   '720': {'id': 720,
#    'is_leafnode': False,
#    'name': 'Put away ingredients',
#    'parent_id': 653,
#    'parent_name': 'Clean up'},
#   '724': {'id': 724,
#    'is_leafnode': True,
#    'name': 'Put away bell peppers',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 724},
#   '726': {'id': 726,
#    'is_leafnode': True,
#    'name': 'Put away butter',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 726},
#   '729': {'id': 729,
#    'is_leafnode': True,
#    'name': 'Put away carrots',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 729},
#   '730': {'id': 730,
#    'is_leafnode': True,
#    'name': 'Put away celeries',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 730},
#   '733': {'id': 733,
#    'is_leafnode': True,
#    'name': 'Put away cherry tomatoes',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 733},
#   '737': {'id': 737,
#    'is_leafnode': True,
#    'name': 'Put away cinnamon powder',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 737},
#   '752': {'id': 752,
#    'is_leafnode': True,
#    'name': 'Put away cilantro',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 736},
#   '756': {'id': 756,
#    'is_leafnode': True,
#    'name': 'Put away garlic cloves',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 756},
#   '759': {'id': 759,
#    'is_leafnode': True,
#    'name': 'Put away fresh ginger',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 759},
#   '762': {'id': 762,
#    'is_leafnode': True,
#    'name': 'Put away green chilies',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 762},
#   '764': {'id': 764,
#    'is_leafnode': True,
#    'name': 'Put away honey',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 764},
#   '769': {'id': 769,
#    'is_leafnode': True,
#    'name': 'Put away lemon juice',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 769},
#   '770': {'id': 770,
#    'is_leafnode': True,
#    'name': 'Put away lettuce',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 770},
#   '779': {'id': 779,
#    'is_leafnode': True,
#    'name': 'Put away oil',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 779},
#   '782': {'id': 782,
#    'is_leafnode': True,
#    'name': 'Put away onions',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 782},
#   '786': {'id': 786,
#    'is_leafnode': True,
#    'name': 'Put away peanut butter',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 786},
#   '787': {'id': 787,
#    'is_leafnode': True,
#    'name': 'Put away pepper',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 787},
#   '792': {'id': 792,
#    'is_leafnode': True,
#    'name': 'Put away rice vinegar',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 792},
#   '793': {'id': 793,
#    'is_leafnode': True,
#    'name': 'Put away salt',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 793},
#   '796': {'id': 796,
#    'is_leafnode': True,
#    'name': 'Put away sesame oil',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 796},
#   '797': {'id': 797,
#    'is_leafnode': True,
#    'name': 'Put away sesame seeds',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 797},
#   '798': {'id': 798,
#    'is_leafnode': True,
#    'name': 'Put away soy sauce',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 798},
#   '806': {'id': 806,
#    'is_leafnode': True,
#    'name': 'Put away tea leaves',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 806},
#   '808': {'id': 808,
#    'is_leafnode': True,
#    'name': 'Put away tomato',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 808},
#   '815': {'id': 815,
#    'is_leafnode': True,
#    'name': 'Put away white pepper',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 815},
#   '816': {'id': 816,
#    'is_leafnode': True,
#    'name': 'Wipe kitchen countertop',
#    'parent_id': 653,
#    'parent_name': 'Clean up',
#    'unique_id': 816},
#   '817': {'id': 817,
#    'is_leafnode': True,
#    'name': 'Throw out trash or waste',
#    'parent_id': 653,
#    'parent_name': 'Clean up',
#    'unique_id': 817},
#   '818': {'id': 818,
#    'is_leafnode': False,
#    'name': 'Prepare ingredients',
#    'parent_id': 0,
#    'parent_name': 'Making Sesame-Ginger Asian Salad'},
#   '819': {'id': 819,
#    'is_leafnode': False,
#    'name': 'Grate ingredients',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients'},
#   '820': {'id': 820,
#    'is_leafnode': True,
#    'name': 'Grate carrots',
#    'parent_id': 819,
#    'parent_name': 'Grate ingredients',
#    'unique_id': 1364},
#   '821': {'id': 821,
#    'is_leafnode': True,
#    'name': 'Grate ginger',
#    'parent_id': 819,
#    'parent_name': 'Grate ingredients',
#    'unique_id': 1365},
#   '822': {'id': 822,
#    'is_leafnode': False,
#    'name': 'Drain ingredients',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients'},
#   '823': {'id': 823,
#    'is_leafnode': True,
#    'name': 'Drain the oranges, save liquid',
#    'parent_id': 822,
#    'parent_name': 'Drain ingredients',
#    'unique_id': 1366},
#   '826': {'id': 826,
#    'is_leafnode': False,
#    'name': 'Prepare dressing',
#    'parent_id': 0,
#    'parent_name': 'Making Sesame-Ginger Asian Salad'},
#   '827': {'id': 827,
#    'is_leafnode': False,
#    'name': 'Add ingredients (dressing)',
#    'parent_id': 826,
#    'parent_name': 'Prepare dressing'},
#   '830': {'id': 830,
#    'is_leafnode': True,
#    'name': 'Add almonds',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 7},
#   '832': {'id': 832,
#    'is_leafnode': True,
#    'name': 'Add bell peppers',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 9},
#   '833': {'id': 833,
#    'is_leafnode': True,
#    'name': 'Add black pepper',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 10},
#   '836': {'id': 836,
#    'is_leafnode': True,
#    'name': 'Add cardamom to a mixing bowl',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 1006},
#   '837': {'id': 837,
#    'is_leafnode': True,
#    'name': 'Add carrots',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 14},
#   '838': {'id': 838,
#    'is_leafnode': True,
#    'name': 'Add celeries',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 15},
#   '842': {'id': 842,
#    'is_leafnode': True,
#    'name': 'Add chili powder',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 19},
#   '844': {'id': 844,
#    'is_leafnode': True,
#    'name': 'Add cilantro',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 21},
#   '845': {'id': 845,
#    'is_leafnode': True,
#    'name': 'Add cinnamon powder',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 22},
#   '850': {'id': 850,
#    'is_leafnode': True,
#    'name': 'Add cilantro',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 21},
#   '860': {'id': 860,
#    'is_leafnode': True,
#    'name': 'Add cilantro',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 21},
#   '864': {'id': 864,
#    'is_leafnode': True,
#    'name': 'Add garlic cloves',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 41},
#   '865': {'id': 865,
#    'is_leafnode': True,
#    'name': 'Add garlic paste',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 42},
#   '867': {'id': 867,
#    'is_leafnode': True,
#    'name': 'Add fresh ginger',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 44},
#   '868': {'id': 868,
#    'is_leafnode': True,
#    'name': 'Add ginger garlic paste to a mixing bowl',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 1038},
#   '869': {'id': 869,
#    'is_leafnode': True,
#    'name': 'Add ginger paste',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 46},
#   '872': {'id': 872,
#    'is_leafnode': True,
#    'name': 'Add honey',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 49},
#   '876': {'id': 876,
#    'is_leafnode': True,
#    'name': 'Add lemon to a mixing bowl',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 1046},
#   '877': {'id': 877,
#    'is_leafnode': True,
#    'name': 'Add lemon juice',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 54},
#   '880': {'id': 880,
#    'is_leafnode': True,
#    'name': 'Add lime juice to a mixing bowl',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 1050},
#   '881': {'id': 881,
#    'is_leafnode': True,
#    'name': 'Add mayonnaise',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 58},
#   '883': {'id': 883,
#    'is_leafnode': True,
#    'name': 'Add mustard',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 60},
#   '887': {'id': 887,
#    'is_leafnode': True,
#    'name': 'Add oil',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 64},
#   '888': {'id': 888,
#    'is_leafnode': True,
#    'name': 'Add olive oil to a bowl',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 2114},
#   '890': {'id': 890,
#    'is_leafnode': True,
#    'name': 'Add onions',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 67},
#   '892': {'id': 892,
#    'is_leafnode': True,
#    'name': 'Add oyster sauce to a bowl',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 2118},
#   '893': {'id': 893,
#    'is_leafnode': True,
#    'name': 'Add parsley',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 70},
#   '894': {'id': 894,
#    'is_leafnode': True,
#    'name': 'Add peanut butter',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 71},
#   '895': {'id': 895,
#    'is_leafnode': True,
#    'name': 'Add pepper',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 72},
#   '900': {'id': 900,
#    'is_leafnode': True,
#    'name': 'Add vinegar',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 98},
#   '901': {'id': 901,
#    'is_leafnode': True,
#    'name': 'Add salt',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 78},
#   '902': {'id': 902,
#    'is_leafnode': True,
#    'name': 'Add scallion',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 79},
#   '904': {'id': 904,
#    'is_leafnode': True,
#    'name': 'Add sesame oil',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 81},
#   '905': {'id': 905,
#    'is_leafnode': True,
#    'name': 'Add sesame seeds',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 82},
#   '906': {'id': 906,
#    'is_leafnode': True,
#    'name': 'Add soy sauce',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 83},
#   '907': {'id': 907,
#    'is_leafnode': True,
#    'name': 'Add spinach to a mixing bowl',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 1077},
#   '909': {'id': 909,
#    'is_leafnode': True,
#    'name': 'Add sugar',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 86},
#   '910': {'id': 910,
#    'is_leafnode': True,
#    'name': 'Add tamari',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 87},
#   '915': {'id': 915,
#    'is_leafnode': True,
#    'name': 'Add sesame oil',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 81},
#   '920': {'id': 920,
#    'is_leafnode': True,
#    'name': 'Add turmeric powder',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 97},
#   '923': {'id': 923,
#    'is_leafnode': True,
#    'name': 'Add white pepper',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 100},
#   '924': {'id': 924,
#    'is_leafnode': False,
#    'name': 'Mix ingredients',
#    'parent_id': 826,
#    'parent_name': 'Prepare dressing'},
#   '925': {'id': 925,
#    'is_leafnode': True,
#    'name': 'Whisk the mix of ingredients',
#    'parent_id': 924,
#    'parent_name': 'Mix ingredients',
#    'unique_id': 1464},
#   '926': {'id': 926,
#    'is_leafnode': True,
#    'name': 'Shake the mix of ingredients',
#    'parent_id': 924,
#    'parent_name': 'Mix ingredients',
#    'unique_id': 1465},
#   '928': {'id': 928,
#    'is_leafnode': False,
#    'name': 'Make salad',
#    'parent_id': 0,
#    'parent_name': 'Making Sesame-Ginger Asian Salad'},
#   '929': {'id': 929,
#    'is_leafnode': False,
#    'name': 'Add ingredients (salad)',
#    'parent_id': 928,
#    'parent_name': 'Make salad'},
#   '932': {'id': 932,
#    'is_leafnode': True,
#    'name': 'Add almonds',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 7},
#   '934': {'id': 934,
#    'is_leafnode': True,
#    'name': 'Add bell peppers',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 9},
#   '939': {'id': 939,
#    'is_leafnode': True,
#    'name': 'Add carrots',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 14},
#   '940': {'id': 940,
#    'is_leafnode': True,
#    'name': 'Add celeries',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 15},
#   '943': {'id': 943,
#    'is_leafnode': True,
#    'name': 'Add cherry tomatoes',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 18},
#   '944': {'id': 944,
#    'is_leafnode': True,
#    'name': 'Add chili powder',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 19},
#   '946': {'id': 946,
#    'is_leafnode': True,
#    'name': 'Add cilantro',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 21},
#   '952': {'id': 952,
#    'is_leafnode': True,
#    'name': 'Add cilantro',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 21},
#   '953': {'id': 953,
#    'is_leafnode': True,
#    'name': 'Add cucumber',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 28},
#   '959': {'id': 959,
#    'is_leafnode': True,
#    'name': 'Add feta cheese',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 34},
#   '962': {'id': 962,
#    'is_leafnode': True,
#    'name': 'Add cilantro',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 21},
#   '967': {'id': 967,
#    'is_leafnode': True,
#    'name': 'Add garlic paste',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 42},
#   '968': {'id': 968,
#    'is_leafnode': True,
#    'name': 'Add garlic powder',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 43},
#   '969': {'id': 969,
#    'is_leafnode': True,
#    'name': 'Add fresh ginger',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 44},
#   '971': {'id': 971,
#    'is_leafnode': True,
#    'name': 'Add ginger paste',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 46},
#   '972': {'id': 972,
#    'is_leafnode': True,
#    'name': 'Add green chilies',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 47},
#   '974': {'id': 974,
#    'is_leafnode': True,
#    'name': 'Add honey',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 49},
#   '975': {'id': 975,
#    'is_leafnode': True,
#    'name': 'Add hot sauce',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 50},
#   '979': {'id': 979,
#    'is_leafnode': True,
#    'name': 'Add lemon juice',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 54},
#   '980': {'id': 980,
#    'is_leafnode': True,
#    'name': 'Add lettuce',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 55},
#   '983': {'id': 983,
#    'is_leafnode': True,
#    'name': 'Add mayonnaise',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 58},
#   '985': {'id': 985,
#    'is_leafnode': True,
#    'name': 'Add mustard',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 60},
#   '989': {'id': 989,
#    'is_leafnode': True,
#    'name': 'Add oil',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 64},
#   '992': {'id': 992,
#    'is_leafnode': True,
#    'name': 'Add onions',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 67},
#   '996': {'id': 996,
#    'is_leafnode': True,
#    'name': 'Add peanut butter',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 71},
#   '997': {'id': 997,
#    'is_leafnode': True,
#    'name': 'Add pepper',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 72},
#   '1003': {'id': 1003,
#    'is_leafnode': True,
#    'name': 'Add salt',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 78},
#   '1004': {'id': 1004,
#    'is_leafnode': True,
#    'name': 'Add scallion',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 79},
#   '1006': {'id': 1006,
#    'is_leafnode': True,
#    'name': 'Add sesame oil',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 81},
#   '1007': {'id': 1007,
#    'is_leafnode': True,
#    'name': 'Add sesame seeds',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 82},
#   '1008': {'id': 1008,
#    'is_leafnode': True,
#    'name': 'Add soy sauce',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 83},
#   '1017': {'id': 1017,
#    'is_leafnode': True,
#    'name': 'Add sesame oil',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 81},
#   '1022': {'id': 1022,
#    'is_leafnode': True,
#    'name': 'Add turmeric powder',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 97},
#   '1026': {'id': 1026,
#    'is_leafnode': True,
#    'name': 'Add the prepared mix of vegetables to a bowl',
#    'parent_id': 928,
#    'parent_name': 'Make salad',
#    'unique_id': 1563},
#   '1027': {'id': 1027,
#    'is_leafnode': False,
#    'name': 'Add the prepared dressing to a bowl',
#    'parent_id': 928,
#    'parent_name': 'Make salad'},
#   '1028': {'id': 1028,
#    'is_leafnode': True,
#    'name': 'Whisk the dressing before pouring',
#    'parent_id': 1027,
#    'parent_name': 'Add the prepared dressing to a bowl',
#    'unique_id': 1564},
#   '1029': {'id': 1029,
#    'is_leafnode': True,
#    'name': 'Pour the dressing',
#    'parent_id': 1027,
#    'parent_name': 'Add the prepared dressing to a bowl',
#    'unique_id': 1565},
#   '1030': {'id': 1030,
#    'is_leafnode': False,
#    'name': 'Combine the ingredients',
#    'parent_id': 928,
#    'parent_name': 'Make salad'},
#   '1031': {'id': 1031,
#    'is_leafnode': True,
#    'name': 'Toss the mixture',
#    'parent_id': 1030,
#    'parent_name': 'Combine the ingredients',
#    'unique_id': 1566},
#   '1032': {'id': 1032,
#    'is_leafnode': True,
#    'name': 'Stir the mixture',
#    'parent_id': 1030,
#    'parent_name': 'Combine the ingredients',
#    'unique_id': 1567},
#   '1033': {'id': 1033,
#    'is_leafnode': True,
#    'name': 'Mistake',
#    'parent_id': 0,
#    'parent_name': 'Making Sesame-Ginger Asian Salad',
#    'unique_id': 10000},
#   '1034': {'id': 1034,
#    'is_leafnode': True,
#    'name': 'Wash celeries',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 112},
#   '1035': {'id': 1035,
#    'is_leafnode': True,
#    'name': 'Wash lettuce',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 152},
#   '1036': {'id': 1036,
#    'is_leafnode': True,
#    'name': 'Cut onions',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 356},
#   '1037': {'id': 1037,
#    'is_leafnode': True,
#    'name': 'Cut bell peppers',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 298},
#   '1038': {'id': 1038,
#    'is_leafnode': True,
#    'name': 'Cut carrots',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 303},
#   '1039': {'id': 1039,
#    'is_leafnode': True,
#    'name': 'Cut celeries',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 304},
#   '1040': {'id': 1040,
#    'is_leafnode': True,
#    'name': 'Cut lettuce',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 344},
#   '1041': {'id': 1041,
#    'is_leafnode': True,
#    'name': 'Check paper recipe',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 502},
#   '1042': {'id': 1042,
#    'is_leafnode': True,
#    'name': 'Peel carrots',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 207},
#   '1043': {'id': 1043,
#    'is_leafnode': True,
#    'name': 'Wash carrots',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 111},
#   '1044': {'id': 1044,
#    'is_leafnode': True,
#    'name': 'Wipe hands',
#    'parent_id': 653,
#    'parent_name': 'Clean up',
#    'unique_id': 4},
#   '1045': {'id': 1045,
#    'is_leafnode': True,
#    'name': 'Check paper recipe',
#    'parent_id': 819,
#    'parent_name': 'Grate ingredients',
#    'unique_id': 502},
#   '1046': {'id': 1046,
#    'is_leafnode': True,
#    'name': 'Cut scallion',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 368},
#   '1047': {'id': 1047,
#    'is_leafnode': True,
#    'name': 'Cut cilantro',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 310},
#   '1048': {'id': 1048,
#    'is_leafnode': True,
#    'name': 'Cut bell peppers',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 298},
#   '1049': {'id': 1049,
#    'is_leafnode': True,
#    'name': 'Wash bell peppers',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 106},
#   '1050': {'id': 1050,
#    'is_leafnode': True,
#    'name': 'Cut ginger',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 1909},
#   '1051': {'id': 1051,
#    'is_leafnode': True,
#    'name': 'Peel fresh ginger',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 237},
#   '1052': {'id': 1052,
#    'is_leafnode': True,
#    'name': 'Peel garlic cloves',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 234},
#   '1053': {'id': 1053,
#    'is_leafnode': True,
#    'name': 'Cut garlic cloves',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 330},
#   '1054': {'id': 1054,
#    'is_leafnode': True,
#    'name': 'Cut spring onions',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 374},
#   '1055': {'id': 1055,
#    'is_leafnode': True,
#    'name': 'Cut cilantro',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 310},
#   '1056': {'id': 1056,
#    'is_leafnode': True,
#    'name': 'Taste the recipe',
#    'parent_id': 928,
#    'parent_name': 'Make salad',
#    'unique_id': 486},
#   '1057': {'id': 1057,
#    'is_leafnode': True,
#    'name': 'Get a bowl',
#    'parent_id': 504,
#    'parent_name': 'Get Ingredients',
#    'unique_id': 2181},
#   '1058': {'id': 1058,
#    'is_leafnode': True,
#    'name': 'Get plate',
#    'parent_id': 633,
#    'parent_name': 'Serve',
#    'unique_id': 623},
#   '1059': {'id': 1059,
#    'is_leafnode': True,
#    'name': 'Wash fresh parsley',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 135},
#   '1060': {'id': 1060,
#    'is_leafnode': True,
#    'name': 'Remove seeds from celeries',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 400},
#   '1061': {'id': 1061,
#    'is_leafnode': True,
#    'name': 'Get a bowl',
#    'parent_id': 633,
#    'parent_name': 'Serve',
#    'unique_id': 2181},
#   '1062': {'id': 1062,
#    'is_leafnode': True,
#    'name': 'Check paper recipe',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 502},
#   '1063': {'id': 1063,
#    'is_leafnode': True,
#    'name': 'Remove seeds from bell peppers',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 394},
#   '1064': {'id': 1064,
#    'is_leafnode': True,
#    'name': 'Peel onions',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 260},
#   '1065': {'id': 1065,
#    'is_leafnode': True,
#    'name': 'Check paper recipe',
#    'parent_id': 600,
#    'parent_name': 'Get kitchenware & utensils',
#    'unique_id': 502},
#   '1066': {'id': 1066,
#    'is_leafnode': True,
#    'name': 'Wash hands',
#    'parent_id': 653,
#    'parent_name': 'Clean up',
#    'unique_id': 3},
#   '1067': {'id': 1067,
#    'is_leafnode': True,
#    'name': 'Wash cilantro',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 118},
#   '1068': {'id': 1068,
#    'is_leafnode': True,
#    'name': 'Remove seeds from carrots',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 399},
#   '1069': {'id': 1069,
#    'is_leafnode': True,
#    'name': 'Check paper recipe',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 502},
#   '1070': {'id': 1070,
#    'is_leafnode': True,
#    'name': 'Add sesame oil',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 81},
#   '1071': {'id': 1071,
#    'is_leafnode': True,
#    'name': 'Add sesame oil',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'unique_id': 81},
#   '1072': {'id': 1072,
#    'is_leafnode': True,
#    'name': 'Check paper recipe',
#    'parent_id': 826,
#    'parent_name': 'Prepare dressing',
#    'unique_id': 502},
#   '1073': {'id': 1073,
#    'is_leafnode': True,
#    'name': 'Check paper recipe',
#    'parent_id': 928,
#    'parent_name': 'Make salad',
#    'unique_id': 502},
#   '1074': {'id': 1074,
#    'is_leafnode': True,
#    'name': 'Check paper recipe',
#    'parent_id': 1030,
#    'parent_name': 'Combine the ingredients',
#    'unique_id': 502},
#   '1075': {'id': 1075,
#    'is_leafnode': True,
#    'name': 'Wipe hands',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 4},
#   '1076': {'id': 1076,
#    'is_leafnode': True,
#    'name': 'Wash cabbage',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 109},
#   '1077': {'id': 1077,
#    'is_leafnode': True,
#    'name': 'Wash cilantro',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 118},
#   '1078': {'id': 1078,
#    'is_leafnode': True,
#    'name': 'Cut cabbage',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 301},
#   '1079': {'id': 1079,
#    'is_leafnode': True,
#    'name': 'Check paper recipe',
#    'parent_id': 0,
#    'parent_name': 'Making Sesame-Ginger Asian Salad',
#    'unique_id': 502},
#   '1080': {'id': 1080,
#    'is_leafnode': True,
#    'name': 'Measure the temperature using an instant thermometer',
#    'parent_id': 0,
#    'parent_name': 'Making Sesame-Ginger Asian Salad',
#    'unique_id': 488},
#   '1081': {'id': 1081,
#    'is_leafnode': True,
#    'name': 'Wash bell peppers',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 106},
#   '1082': {'id': 1082,
#    'is_leafnode': True,
#    'name': 'Remove seeds from bell peppers',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 394},
#   '1083': {'id': 1083,
#    'is_leafnode': True,
#    'name': 'Taste the recipe',
#    'parent_id': 1030,
#    'parent_name': 'Combine the ingredients',
#    'unique_id': 486},
#   '1084': {'id': 1084,
#    'is_leafnode': True,
#    'name': 'Add onions',
#    'parent_id': 826,
#    'parent_name': 'Prepare dressing',
#    'unique_id': 67},
#   '1085': {'id': 1085,
#    'is_leafnode': True,
#    'name': 'Add cilantro',
#    'parent_id': 826,
#    'parent_name': 'Prepare dressing',
#    'unique_id': 21},
#   '1086': {'id': 1086,
#    'is_leafnode': True,
#    'name': 'Cut garlic cloves',
#    'parent_id': 826,
#    'parent_name': 'Prepare dressing',
#    'unique_id': 330},
#   '1087': {'id': 1087,
#    'is_leafnode': True,
#    'name': 'Taste the recipe',
#    'parent_id': 924,
#    'parent_name': 'Mix ingredients',
#    'unique_id': 486},
#   '1088': {'id': 1088,
#    'is_leafnode': True,
#    'name': 'Wash ginger',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 1908},
#   '1089': {'id': 1089,
#    'is_leafnode': True,
#    'name': 'Taste the recipe',
#    'parent_id': 633,
#    'parent_name': 'Serve',
#    'unique_id': 486},
#   '1090': {'id': 1090,
#    'is_leafnode': True,
#    'name': 'Peel garlic cloves',
#    'parent_id': 929,
#    'parent_name': 'Add ingredients (salad)',
#    'unique_id': 234},
#   '1091': {'id': 1091,
#    'is_leafnode': True,
#    'name': 'Cut cilantro',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 310},
#   '1092': {'id': 1092,
#    'is_leafnode': True,
#    'name': 'Peel coriander leaves',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 220},
#   '1093': {'id': 1093,
#    'is_leafnode': True,
#    'name': 'Peel fresh cilantro',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 230},
#   '1094': {'id': 1094,
#    'is_leafnode': True,
#    'name': 'Cut spinach',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 373},
#   '1095': {'id': 1095,
#    'is_leafnode': True,
#    'name': 'Cut sesame seeds',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 371},
#   '1096': {'id': 1096,
#    'is_leafnode': True,
#    'name': 'Cut chili powder',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 308},
#   '1097': {'id': 1097,
#    'is_leafnode': True,
#    'name': 'Cut almonds',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 296},
#   '1098': {'id': 1098,
#    'is_leafnode': True,
#    'name': 'Cut ginger garlic paste',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 334},
#   '1099': {'id': 1099,
#    'is_leafnode': True,
#    'name': 'Cut parsley',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 359},
#   '1100': {'id': 1100,
#    'is_leafnode': True,
#    'name': 'Check paper recipe',
#    'parent_id': 1027,
#    'parent_name': 'Add the prepared dressing to a bowl',
#    'unique_id': 502},
#   '1101': {'id': 1101,
#    'is_leafnode': True,
#    'name': 'Visually inspect the recipe',
#    'parent_id': 0,
#    'parent_name': 'Making Sesame-Ginger Asian Salad',
#    'unique_id': 489},
#   '1102': {'id': 1102,
#    'is_leafnode': True,
#    'name': 'Remove seeds from lettuce',
#    'parent_id': 818,
#    'parent_name': 'Prepare ingredients',
#    'unique_id': 440},
#   '1103': {'id': 1103,
#    'is_leafnode': True,
#    'name': 'Wash spring onions',
#    'parent_id': 0,
#    'parent_name': 'Making Sesame-Ginger Asian Salad',
#    'unique_id': 182},
#   '1104': {'id': 1104,
#    'is_leafnode': True,
#    'name': 'Check phone',
#    'parent_id': 0,
#    'parent_name': 'Making Sesame-Ginger Asian Salad',
#    'unique_id': 499},
#   '1105': {'id': 1105,
#    'is_leafnode': True,
#    'name': 'Wash garlic cloves',
#    'parent_id': 0,
#    'parent_name': 'Making Sesame-Ginger Asian Salad',
#    'unique_id': 138},
#   '1106': {'id': 1106,
#    'is_leafnode': True,
#    'name': 'Cut cucumber',
#    'parent_id': 0,
#    'parent_name': 'Making Sesame-Ginger Asian Salad',
#    'unique_id': 317},
#   '1107': {'id': 1107,
#    'is_leafnode': True,
#    'name': 'Wash cherry tomatoes',
#    'parent_id': 0,
#    'parent_name': 'Making Sesame-Ginger Asian Salad',
#    'unique_id': 115},
#   '1108': {'id': 1108,
#    'is_leafnode': True,
#    'name': 'Add lemon juice',
#    'parent_id': 0,
#    'parent_name': 'Making Sesame-Ginger Asian Salad',
#    'unique_id': 54},
#   '1109': {'id': 1109,
#    'is_leafnode': True,
#    'name': 'Add sesame seeds',
#    'parent_id': 0,
#    'parent_name': 'Making Sesame-Ginger Asian Salad',
#    'unique_id': 82},
#   '1110': {'id': 1110,
#    'is_leafnode': True,
#    'name': 'Place the skillet or pan or pot on the stove',
#    'parent_id': 0,
#    'parent_name': 'Making Sesame-Ginger Asian Salad',
#    'unique_id': 496},
#   '1111': {'id': 1111,
#    'is_leafnode': True,
#    'name': 'Turn on the stove',
#    'parent_id': 0,
#    'parent_name': 'Making Sesame-Ginger Asian Salad',
#    'unique_id': 491},
#   '1112': {'id': 1112,
#    'is_leafnode': True,
#    'name': 'Remove the skillet or pan or pot from the stove',
#    'parent_id': 0,
#    'parent_name': 'Making Sesame-Ginger Asian Salad',
#    'unique_id': 497},
#   '1113': {'id': 1113,
#    'is_leafnode': True,
#    'name': 'Turn off the stove',
#    'parent_id': 0,
#    'parent_name': 'Making Sesame-Ginger Asian Salad',
#    'unique_id': 493},
#   '1114': {'id': 1114,
#    'name': 'Add agave to a mixing bowl',
#    'parent_id': 827,
#    'parent_name': 'Add ingredients (dressing)',
#    'is_leafnode': True,
#    'unique_id': 999},
#   '1115': {'id': 1115,
#    'name': 'Grate garlic',
#    'parent_id': 819,
#    'parent_name': 'Grate ingredients',
#    'is_leafnode': True,
#    'unique_id': 2323}},
#  'Cooking Noodles': {'0': {'id': 0,
#    'is_leafnode': False,
# ...
#    'parent_id': 654,
#    'parent_name': 'Wash kitchenware & utensils',
#    'unique_id': 658},
#   '662': {'id': 662,
#    'is_leafnode': True,
#    'name': 'Wash cup or mug',
#    'parent_id': 654,
#    'parent_name': 'Wash kitchenware & utensils',
#    'unique_id': 662},
#   '664': {'id': 664,
#    'is_leafnode': True,
#    'name': 'Wash electric kettle',
#    'parent_id': 654,
#    'parent_name': 'Wash kitchenware & utensils',
#    'unique_id': 664},
#   '669': {'id': 669,
#    'is_leafnode': True,
#    'name': 'Wash kitchen tong',
#    'parent_id': 654,
#    'parent_name': 'Wash kitchenware & utensils',
#    'unique_id': 669},
#   '671': {'id': 671,
#    'is_leafnode': True,
#    'name': 'Wash knife',
#    'parent_id': 654,
#    'parent_name': 'Wash kitchenware & utensils',
#    'unique_id': 671},
#   '679': {'id': 679,
#    'is_leafnode': True,
#    'name': 'Wash pot or saucepan',
#    'parent_id': 654,
#    'parent_name': 'Wash kitchenware & utensils',
#    'unique_id': 679},
#   '681': {'id': 681,
#    'is_leafnode': True,
#    'name': 'Wash sieve',
#    'parent_id': 654,
#    'parent_name': 'Wash kitchenware & utensils',
#    'unique_id': 681},
#   '682': {'id': 682,
#    'is_leafnode': True,
#    'name': 'Wash skillet or frying pan or wok',
#    'parent_id': 654,
#    'parent_name': 'Wash kitchenware & utensils',
#    'unique_id': 682},
#   '684': {'id': 684,
#    'is_leafnode': True,
#    'name': 'Wash spoon',
#    'parent_id': 654,
#    'parent_name': 'Wash kitchenware & utensils',
#    'unique_id': 684},
#   '687': {'id': 687,
#    'is_leafnode': False,
#    'name': 'Put away kitchenware & utensils',
#    'parent_id': 653,
#    'parent_name': 'Clean up'},
#   '691': {'id': 691,
#    'is_leafnode': True,
#    'name': 'Put away chopsticks',
#    'parent_id': 687,
#    'parent_name': 'Put away kitchenware & utensils',
#    'unique_id': 691},
#   '695': {'id': 695,
#    'is_leafnode': True,
#    'name': 'Put away cup or mug',
#    'parent_id': 687,
#    'parent_name': 'Put away kitchenware & utensils',
#    'unique_id': 695},
#   '697': {'id': 697,
#    'is_leafnode': True,
#    'name': 'Put away kettle',
#    'parent_id': 687,
#    'parent_name': 'Put away kitchenware & utensils',
#    'unique_id': 700},
#   '700': {'id': 700,
#    'is_leafnode': True,
#    'name': 'Put away kettle',
#    'parent_id': 687,
#    'parent_name': 'Put away kitchenware & utensils',
#    'unique_id': 700},
#   '702': {'id': 702,
#    'is_leafnode': True,
#    'name': 'Put away kitchen tong',
#    'parent_id': 687,
#    'parent_name': 'Put away kitchenware & utensils',
#    'unique_id': 702},
#   '704': {'id': 704,
#    'is_leafnode': True,
#    'name': 'Put away knife',
#    'parent_id': 687,
#    'parent_name': 'Put away kitchenware & utensils',
#    'unique_id': 704},
#   '712': {'id': 712,
#    'is_leafnode': True,
#    'name': 'Put away pot or saucepan',
#    'parent_id': 687,
#    'parent_name': 'Put away kitchenware & utensils',
#    'unique_id': 712},
#   '717': {'id': 717,
#    'is_leafnode': True,
#    'name': 'Put away spoon',
#    'parent_id': 687,
#    'parent_name': 'Put away kitchenware & utensils',
#    'unique_id': 717},
#   '720': {'id': 720,
#    'is_leafnode': False,
#    'name': 'Put away ingredients',
#    'parent_id': 653,
#    'parent_name': 'Clean up'},
#   '741': {'id': 741,
#    'is_leafnode': True,
#    'name': 'Put away coffee grounds',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 741},
#   '746': {'id': 746,
#    'is_leafnode': True,
#    'name': 'Put away dried herbs',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 746},
#   '769': {'id': 769,
#    'is_leafnode': True,
#    'name': 'Put away lemon juice',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 769},
#   '774': {'id': 774,
#    'is_leafnode': True,
#    'name': 'Put away milk',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 774},
#   '777': {'id': 777,
#    'is_leafnode': True,
#    'name': 'Put away noodles',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 777},
#   '778': {'id': 778,
#    'is_leafnode': True,
#    'name': 'Put away nutmeg',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 778},
#   '782': {'id': 782,
#    'is_leafnode': True,
#    'name': 'Put away onions',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 782},
#   '794': {'id': 794,
#    'is_leafnode': True,
#    'name': 'Put away scallion',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 794},
#   '801': {'id': 801,
#    'is_leafnode': True,
#    'name': 'Put away sugar',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 801},
#   '803': {'id': 803,
#    'is_leafnode': True,
#    'name': 'Put away tea bag',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 803},
#   '804': {'id': 804,
#    'is_leafnode': True,
#    'name': 'Put away tea bag',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 803},
#   '806': {'id': 806,
#    'is_leafnode': True,
#    'name': 'Put away tea leaves',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 806},
#   '814': {'id': 814,
#    'is_leafnode': True,
#    'name': 'Put away water',
#    'parent_id': 720,
#    'parent_name': 'Put away ingredients',
#    'unique_id': 814},
#   '816': {'id': 816,
#    'is_leafnode': True,
#    'name': 'Wipe kitchen countertop',
#    'parent_id': 653,
#    'parent_name': 'Clean up',
#    'unique_id': 816},
#   '817': {'id': 817,
#    'is_leafnode': True,
#    'name': 'Throw out trash or waste',
#    'parent_id': 653,
#    'parent_name': 'Clean up',
#    'unique_id': 817},
#   '818': {'id': 818,
#    'is_leafnode': False,
#    'name': 'Make milk tea',
#    'parent_id': 0,
#    'parent_name': 'Making Milk Tea'},
#   '819': {'id': 819,
#    'is_leafnode': False,
#    'name': 'Boil water in a pot or saucepan or a kettle',
#    'parent_id': 818,
#    'parent_name': 'Make milk tea'},
#   '820': {'id': 820,
#    'is_leafnode': True,
#    'name': 'Get a pot or saucepan',
#    'parent_id': 819,
#    'parent_name': 'Boil water in a pot or saucepan or a kettle',
#    'unique_id': 1333},
#   '821': {'id': 821,
#    'is_leafnode': True,
#    'name': 'Add water',
#    'parent_id': 819,
#    'parent_name': 'Boil water in a pot or saucepan or a kettle',
#    'unique_id': 99},
#   '822': {'id': 822,
#    'is_leafnode': True,
#    'name': 'Turn on the stove',
#    'parent_id': 819,
#    'parent_name': 'Boil water in a pot or saucepan or a kettle',
#    'unique_id': 491},
#   '823': {'id': 823,
#    'is_leafnode': True,
#    'name': 'Adjust the stove heat',
#    'parent_id': 819,
#    'parent_name': 'Boil water in a pot or saucepan or a kettle',
#    'unique_id': 492},
#   '824': {'id': 824,
#    'is_leafnode': True,
#    'name': 'Wait until water boils',
#    'parent_id': 819,
#    'parent_name': 'Boil water in a pot or saucepan or a kettle',
#    'unique_id': 1337},
#   '825': {'id': 825,
#    'is_leafnode': False,
#    'name': 'Boil water in an electric kettle',
#    'parent_id': 818,
#    'parent_name': 'Make milk tea'},
#   '826': {'id': 826,
#    'is_leafnode': True,
#    'name': 'Get an electric kettle',
#    'parent_id': 825,
#    'parent_name': 'Boil water in an electric kettle',
#    'unique_id': 1338},
#   '827': {'id': 827,
#    'is_leafnode': True,
#    'name': 'Fill an electric kettle with water',
#    'parent_id': 825,
#    'parent_name': 'Boil water in an electric kettle',
#    'unique_id': 2205},
#   '829': {'id': 829,
#    'is_leafnode': True,
#    'name': 'Turn on the stove',
#    'parent_id': 825,
#    'parent_name': 'Boil water in an electric kettle',
#    'unique_id': 491},
#   '830': {'id': 830,
#    'is_leafnode': True,
#    'name': 'Wait until water boils',
#    'parent_id': 825,
#    'parent_name': 'Boil water in an electric kettle',
#    'unique_id': 1337},
#   '831': {'id': 831,
#    'is_leafnode': False,
#    'name': 'Steep the tea',
#    'parent_id': 818,
#    'parent_name': 'Make milk tea'},
#   '832': {'id': 832,
#    'is_leafnode': True,
#    'name': 'Pour hot water to a cup or mug',
#    'parent_id': 831,
#    'parent_name': 'Steep the tea',
#    'unique_id': 2238},
#   '833': {'id': 833,
#    'is_leafnode': True,
#    'name': 'Get tea leaves',
#    'parent_id': 831,
#    'parent_name': 'Steep the tea',
#    'unique_id': 590},
#   '834': {'id': 834,
#    'is_leafnode': True,
#    'name': 'Get tea bag',
#    'parent_id': 831,
#    'parent_name': 'Steep the tea',
#    'unique_id': 587},
#   '836': {'id': 836,
#    'is_leafnode': True,
#    'name': 'Add tea leaves',
#    'parent_id': 831,
#    'parent_name': 'Steep the tea',
#    'unique_id': 91},
#   '837': {'id': 837,
#    'is_leafnode': True,
#    'name': 'Add tea bags to hot water',
#    'parent_id': 831,
#    'parent_name': 'Steep the tea',
#    'unique_id': 1348},
#   '839': {'id': 839,
#    'is_leafnode': True,
#    'name': 'Add cinnamon stick',
#    'parent_id': 831,
#    'parent_name': 'Steep the tea',
#    'unique_id': 650},
#   '840': {'id': 840,
#    'is_leafnode': True,
#    'name': 'Add nutmeg',
#    'parent_id': 831,
#    'parent_name': 'Steep the tea',
#    'unique_id': 63},
#   '841': {'id': 841,
#    'is_leafnode': True,
#    'name': 'Stir the tea',
#    'parent_id': 831,
#    'parent_name': 'Steep the tea',
#    'unique_id': 652},
#   '842': {'id': 842,
#    'is_leafnode': True,
#    'name': 'Steep the tea until ready',
#    'parent_id': 831,
#    'parent_name': 'Steep the tea',
#    'unique_id': 1353},
#   '843': {'id': 843,
#    'is_leafnode': True,
#    'name': 'Remove the tea bag',
#    'parent_id': 831,
#    'parent_name': 'Steep the tea',
#    'unique_id': 1354},
#   '846': {'id': 846,
#    'is_leafnode': True,
#    'name': 'Drain the tea from tea bag or leave or infuser',
#    'parent_id': 831,
#    'parent_name': 'Steep the tea',
#    'unique_id': 1357},
#   '847': {'id': 847,
#    'is_leafnode': False,
#    'name': 'Add milk',
#    'parent_id': 818,
#    'parent_name': 'Make milk tea'},
#   '848': {'id': 848,
#    'is_leafnode': True,
#    'name': 'Get milk',
#    'parent_id': 847,
#    'parent_name': 'Add milk',
#    'unique_id': 558},
#   '849': {'id': 849,
#    'is_leafnode': True,
#    'name': 'Pour milk into the tea',
#    'parent_id': 847,
#    'parent_name': 'Add milk',
#    'unique_id': 1359},
#   '850': {'id': 850,
#    'is_leafnode': True,
#    'name': 'Stir milk with a spoon to mix well with water and tea',
#    'parent_id': 847,
#    'parent_name': 'Add milk',
#    'unique_id': 1360},
#   '851': {'id': 851,
#    'is_leafnode': False,
#    'name': 'Add sweetener of your choice',
#    'parent_id': 818,
#    'parent_name': 'Make milk tea'},
#   '852': {'id': 852,
#    'is_leafnode': True,
#    'name': 'Stir milk with a spoon to mix well with water and tea',
#    'parent_id': 851,
#    'parent_name': 'Add sweetener of your choice',
#    'unique_id': 1360},
#   '853': {'id': 853,
#    'is_leafnode': False,
#    'name': 'Simmer for an additional 2-3 minutes.',
#    'parent_id': 818,
#    'parent_name': 'Make milk tea'},
#   '854': {'id': 854,
#    'is_leafnode': True,
#    'name': 'Simmer the tea over low heat',
#    'parent_id': 853,
#    'parent_name': 'Simmer for an additional 2-3 minutes.',
#    'unique_id': 1362},
#   '855': {'id': 855,
#    'is_leafnode': True,
#    'name': 'Stir the tea',
#    'parent_id': 853,
#    'parent_name': 'Simmer for an additional 2-3 minutes.',
#    'unique_id': 652},
#   '856': {'id': 856,
#    'is_leafnode': True,
#    'name': 'Mistake',
#    'parent_id': 0,
#    'parent_name': 'Making Milk Tea',
#    'unique_id': 10000},
#   '857': {'id': 857,
#    'is_leafnode': True,
#    'name': 'Get sugar',
#    'parent_id': 851,
#    'parent_name': 'Add sweetener of your choice',
#    'unique_id': 585},
#   '858': {'id': 858,
#    'is_leafnode': True,
#    'name': 'Add sugar',
#    'parent_id': 818,
#    'parent_name': 'Make milk tea',
#    'unique_id': 86},
#   '859': {'id': 859,
#    'is_leafnode': True,
#    'name': 'Add sugar',
#    'parent_id': 851,
#    'parent_name': 'Add sweetener of your choice',
#    'unique_id': 86},
#   '860': {'id': 860,
#    'is_leafnode': True,
#    'name': 'Visually inspect the recipe',
#    'parent_id': 831,
#    'parent_name': 'Steep the tea',
#    'unique_id': 489},
#   '861': {'id': 861,
#    'is_leafnode': True,
#    'name': 'Taste the recipe',
#    'parent_id': 851,
#    'parent_name': 'Add sweetener of your choice',
#    'unique_id': 486},
#   '862': {'id': 862,
#    'is_leafnode': True,
#    'name': 'Taste the recipe',
#    'parent_id': 847,
#    'parent_name': 'Add milk',
#    'unique_id': 486},
#   '863': {'id': 863,
#    'is_leafnode': True,
#    'name': 'Close the lid of a skillet or pan or pot',
#    'parent_id': 819,
#    'parent_name': 'Boil water in a pot or saucepan or a kettle',
#    'unique_id': 495},
#   '864': {'id': 864,
#    'is_leafnode': True,
#    'name': 'Place the skillet or pan or pot on the stove',
#    'parent_id': 819,
#    'parent_name': 'Boil water in a pot or saucepan or a kettle',
#    'unique_id': 496},
#   '865': {'id': 865,
#    'is_leafnode': True,
#    'name': 'Add sugar',
#    'parent_id': 851,
#    'parent_name': 'Add sweetener of your choice',
#    'unique_id': 86},
#   '866': {'id': 866,
#    'is_leafnode': True,
#    'name': 'Turn off the stove',
#    'parent_id': 819,
#    'parent_name': 'Boil water in a pot or saucepan or a kettle',
#    'unique_id': 493},
#   '867': {'id': 867,
#    'is_leafnode': True,
#    'name': 'Close the lid of a skillet or pan or pot',
#    'parent_id': 831,
#    'parent_name': 'Steep the tea',
#    'unique_id': 495},
#   '868': {'id': 868,
#    'is_leafnode': True,
#    'name': 'Lift the lid of a skillet or pan or pot',
#    'parent_id': 831,
#    'parent_name': 'Steep the tea',
#    'unique_id': 494},
#   '869': {'id': 869,
#    'is_leafnode': True,
#    'name': 'Add chocolate',
#    'parent_id': 831,
#    'parent_name': 'Steep the tea',
#    'unique_id': 20},
#   '870': {'id': 870,
#    'is_leafnode': True,
#    'name': 'Add milk',
#    'parent_id': 847,
#    'parent_name': 'Add milk',
#    'unique_id': 59},
#   '871': {'id': 871,
#    'is_leafnode': True,
#    'name': 'Taste the recipe',
#    'parent_id': 633,
#    'parent_name': 'Serve',
#    'unique_id': 486},
#   '872': {'id': 872,
#    'is_leafnode': True,
#    'name': 'Wash hands',
#    'parent_id': 653,
#    'parent_name': 'Clean up',
#    'unique_id': 3},
#   '873': {'id': 873,
#    'is_leafnode': True,
#    'name': 'Wipe hands',
#    'parent_id': 653,
#    'parent_name': 'Clean up',
#    'unique_id': 4},
#   '874': {'id': 874,
#    'is_leafnode': True,
#    'name': 'Measure the temperature using an instant thermometer',
#    'parent_id': 825,
#    'parent_name': 'Boil water in an electric kettle',
#    'unique_id': 488},
#   '875': {'id': 875,
#    'is_leafnode': True,
#    'name': 'Wash tea bag',
#    'parent_id': 831,
#    'parent_name': 'Steep the tea',
#    'unique_id': 185},
#   '876': {'id': 876,
#    'is_leafnode': True,
#    'name': 'Cut tea bag',
#    'parent_id': 831,
#    'parent_name': 'Steep the tea',
#    'unique_id': 377},
#   '877': {'id': 877,
#    'is_leafnode': True,
#    'name': 'Get water',
#    'parent_id': 831,
#    'parent_name': 'Steep the tea',
#    'unique_id': 598},
#   '878': {'id': 878,
#    'is_leafnode': True,
#    'name': 'Add honey',
#    'parent_id': 851,
#    'parent_name': 'Add sweetener of your choice',
#    'unique_id': 49},
#   '879': {'id': 879,
#    'is_leafnode': True,
#    'name': 'Add sugar',
#    'parent_id': 819,
#    'parent_name': 'Boil water in a pot or saucepan or a kettle',
#    'unique_id': 86},
#   '880': {'id': 880,
#    'is_leafnode': True,
#    'name': 'Add coffee grounds',
#    'parent_id': 0,
#    'parent_name': 'Making Milk Tea',
#    'unique_id': 26},
#   '881': {'id': 881,
#    'is_leafnode': True,
#    'name': 'Add lemon juice',
#    'parent_id': 0,
#    'parent_name': 'Making Milk Tea',
#    'unique_id': 54},
#   '882': {'id': 882,
#    'is_leafnode': True,
#    'name': 'Turn on the stove',
#    'parent_id': 0,
#    'parent_name': 'Making Milk Tea',
#    'unique_id': 491},
#   '883': {'id': 883,
#    'is_leafnode': True,
#    'name': 'Add water',
#    'parent_id': 0,
#    'parent_name': 'Making Milk Tea',
#    'unique_id': 99},
#   '884': {'id': 884,
#    'is_leafnode': True,
#    'name': 'Add tea leaves',
#    'parent_id': 0,
#    'parent_name': 'Making Milk Tea',
#    'unique_id': 91},
#   '885': {'id': 885,
#    'is_leafnode': True,
#    'name': 'Add dried herbs',
#    'parent_id': 0,
#    'parent_name': 'Making Milk Tea',
#    'unique_id': 31},
#   '886': {'id': 886,
#    'is_leafnode': True,
#    'name': 'Cut nutmeg',
#    'parent_id': 0,
#    'parent_name': 'Making Milk Tea',
#    'unique_id': 352}}}

# %% [markdown]
# Notes on annotations:
# - just note that there are other interesting text metadata for later
# - Taxonomy is interesting, it is a hierarchical action class definition. We could use this later.
# - Vocabulary contains all of the leaf node classes.
# - I only downloaded the cooking related videos (those with narrations) but vocabulary it contains vocab from other categories. So now lets iterate through the labels for the video samples we downloaded and gather labels.

# %%
keystep_anns.keys()
# Out:
# dict_keys(['taxonomy', 'vocabulary', 'ds', 'annotations'])

# %%
# keystep_anns['taxonomy']

# %%
# build_vocab = {}
# for sample in anns.keys():
#     for segment in anns[sample]['segments']:
#         step_unique_id = segment['step_unique_id']
#         step_name = segment['step_name']

#         if step_unique_id not in build_vocab.keys():
#             build_vocab[step_unique_id] = step_name

# # save
# with open('../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/egoexo-cooking-json', 'w') as fp:
#     json.dump(build_vocab, fp)

# %% [markdown]
# # Preprocess videos - extract frames
# - TODO: Julia: configure cv2 for our GPU

# %%
def get_take_id_from_name(take_name):
    for take_id in anns.keys():
        if anns[take_id]['take_name'] == take_name:
            return take_id
    return None

def get_take_name_from_id(take_id):
    if take_id in anns.keys():
        return anns[take_id]['take_name']
    else:
        return None

# %%
# list of the filepaths that we are interested in. Format is: [(take_name, path_to_mp4), ...]
paths_to_mp4s = []

# ########## Uncomment to process Takes Images ##########
# take_root = 'egoexo4d/egoexo/takes/'
# take_names = os.listdir(take_root)


# for take_name in take_names:
#     path_to_vids = os.path.join(take_root, take_name, 'frame_aligned_videos')

#     if get_take_id_from_name(take_name) is None:
#         continue

#     if os.path.exists(path_to_vids):
#         if use_downscaled == True:
#             if os.path.exists(os.path.join(path_to_vids, 'downscaled/448')):
#                 all_files = os.listdir(os.path.join(path_to_vids, 'downscaled/448'))
#                 mp4_files = [fn for fn in all_files if fn.endswith('.mp4')]
#                 for fn in mp4_files:
#                     # grab the video that we want
#                     if ego_rgb_code in fn and camera in fn:
#                         paths_to_mp4s.append((take_name, os.path.join(path_to_vids, 'downscaled/448', fn)))
#                         break
#         else:
#             all_files = os.listdir(path_to_vids)
#             mp4_files = [fn for fn in all_files if fn.endswith('.mp4')]
#             for fn in mp4_files:
#                     # grab the video that we want
#                     if ego_rgb_code in fn and camera in fn:
#                         paths_to_mp4s.append((take_name, os.path.join(path_to_vids, fn)))
#                         break
# print(paths_to_mp4s)
# print(f'Length of paths_to_mp4s: {len(paths_to_mp4s)}')


# # dictionary that contains the number of frames for each video
# take_to_vlen = {}

# # first get the number of videos to process
# for take_name, video_file in paths_to_mp4s:
#     # read in the video
#     vid = cv2.VideoCapture(video_file)
#     ret, im = vid.read()
#     n_frames = int(vid.get(cv2.CAP_PROP_FRAME_COUNT))
#     take_to_vlen[take_name] = n_frames
# ######################################################################


######### Uncomment to process EgoExo Omnivore features ##########
unique_take_names = set()
take_root = '/local/juro4948/data/egoexo4d/egoexo/features/omnivore_video/'
for fn in os.listdir(take_root):
    take_id = fn.split('_')[0]
    take_name = get_take_name_from_id(take_id)
    if take_name not in unique_take_names and take_name is not None:
        unique_take_names.add(take_name)
take_names = list(unique_take_names)


for take_name in take_names:
    take_id = get_take_id_from_name(take_name)
    for fn in os.listdir(take_root):
        if take_id in fn and camera in fn:
            paths_to_mp4s.append((take_name, os.path.join(take_root, fn)))


print(paths_to_mp4s)
print(f'Length of paths_to_mp4s: {len(paths_to_mp4s)}')


# dictionary that contains the number of frames for each video
take_to_vlen = {}

for take_name, video_file in paths_to_mp4s:
    # read in the video
    video_data = torch.load(video_file)
    vlen= video_data.shape[0]
    n_frames = vlen * 16 + 32  # upsample to 30fps
    take_to_vlen[take_name] = n_frames
#####################################################################
# Out:
# [('fair_cooking_08_2', '/local/juro4948/data/egoexo4d/egoexo/features/omnivore_video/d2e07def-3ea4-4c31-b20c-5f5a7ed52fb9_aria02_rgb.pt'), ('iiith_cooking_122_2', '/local/juro4948/data/egoexo4d/egoexo/features/omnivore_video/a9902d89-3aab-4bce-aa07-720cf12523f6_aria01_rgb.pt'), ('uniandes_cooking_005_2', '/local/juro4948/data/egoexo4d/egoexo/features/omnivore_video/206e9042-02a3-48ac-bed0-45861fe658cb_aria01_rgb.pt'), ('upenn_0711_Cooking_3_5', '/local/juro4948/data/egoexo4d/egoexo/features/omnivore_video/3ca3a186-a650-4f8b-a9d0-f0bdb19bd860_aria01_rgb.pt'), ('georgiatech_cooking_06_03_2', '/local/juro4948/data/egoexo4d/egoexo/features/omnivore_video/13b85191-0a2c-4d0f-a54c-3118f5a96cbb_aria03_rgb.pt'), ('iiith_cooking_128_4', '/local/juro4948/data/egoexo4d/egoexo/features/omnivore_video/c112d4da-5120-47d7-9b05-a4ef68baa226_aria01_rgb.pt'), ('indiana_cooking_21_2', '/local/juro4948/data/egoexo4d/egoexo/features/omnivore_video/a2fc6bb5-ad56-460e-a8ae-64db8080d5ae_aria03_rgb.pt'), ('iiith_cooking_108_4', '/local/juro4948/data/egoexo4d/egoexo/features/omnivore_video/bde0f2f1-a83e-4c29-b182-502ce6d94e21_aria01_rgb.pt'), ('georgiatech_cooking_11_01_6', '/local/juro4948/data/egoexo4d/egoexo/features/omnivore_video/e846fd07-a298-4313-a591-04292b5c5097_aria03_rgb.pt'), ('georgiatech_cooking_09_02_2', '/local/juro4948/data/egoexo4d/egoexo/features/omnivore_video/ce9bec98-3ec5-4189-8f9d-03e3ff3cddda_aria02_rgb.pt'), ('georgiatech_cooking_09_01_6', '/local/juro4948/data/egoexo4d/egoexo/features/omnivore_video/9d7d1acd-671f-4662-9c30-6ec10abd219a_aria04_rgb.pt'), ('sfu_cooking_013_1', '/local/juro4948/data/egoexo4d/egoexo/features/omnivore_video/3059469a-03fc-4ae0-bbf7-b08187d1b290_aria01_rgb.pt'), ('uniandes_cooking_008_4', '/local/juro4948/data/egoexo4d/egoexo/features/omnivore_video/ba2086b2-f43f-4096-8b84-e9a3bfc0020b_aria01_rgb.pt'), ('iiith_cooking_45_1', '/local/juro4948/data/egoexo4d/egoexo/features/omnivore_video/abcd9473-0885-43cc-9e4e-f632f36871d2_aria01_rgb.pt'), ('uniandes_cooking_006_10', '/local/juro4948/data/egoexo4d/egoexo/features/omnivore_video/a0bbdb8e-077b-4881-bbec-30331068a3a7_aria01_rgb.pt'), ('sfu_cooking026_4', '/local/juro4948/data/egoexo4d/egoexo/features/omnivore_video/762f9011-aac1-4bea-b0aa-b21d642a61ea_aria01_rgb.pt'), ('iiith_cooking_12_1', '/local/juro4948/data/egoexo4d/egoexo/features/omnivore_video/be1eb1c1-a45f-4e8b-9ae2-3d8db0af7e59_aria01_rgb.pt'), ('iiith_cooking_28_1', '/local/juro4948/data/egoexo4d/egoexo/features/omnivore_video/819523fa-f601-4ed3-aa1f-b1df5f0482bf_aria01_rgb.pt'), ('upenn_0712_Cooking_4_3', '/local/juro4948/data/egoexo4d/egoexo/features/omnivore_video/be266e24-9627-4b79-84cb-1606b5743f0b_aria01_rgb.pt'), ('upenn_0702_Cooking_3_3', '/local/juro4948/data/egoexo4d/egoexo/features/omnivore_video/a127cf90-51bf-46af-b0ee-ec932ed0b110_aria01_rgb.pt'), ('indiana_cooking_03_3', '/local/juro4948/data/egoexo4d/egoexo/features/omnivore_video/6023b80a-a1af-405b-ae86-6613452a1512_aria02_rgb.pt'), ('iiith_cooking_142_2', '/local/juro4948/data/egoexo4d/egoexo/features/omnivore_video/e68d09a0-fe18-483c-8a7d-24b32f9baa9e_aria01_rgb.pt'), ('sfu_cooking023_4', '/local/juro4948/data/egoexo4d/egoexo/features/omnivore_video/e1475f87-0c9d-4884-b932-140c2a0de3c3_aria01_rgb.pt'), ('sfu_cooking026_8', '/local/juro4948/data/egoexo4d/egoexo/features/omnivore_video/b880f349-0ef2-4470-b597-adbd239ea6e2_aria01_rgb.pt'), ('iiith_cooking_147_2', '/local/juro4948/data/egoexo4d/egoexo/features/omnivore_video/0b771d9f-7bab-4023-ac08-e56c06505946_aria01_rgb.pt'), ('fair_cooking_06_6', '/local/juro4948/data/egoexo4d/egoexo/features/omnivore_video/6bc7a29f-3397-4549-9ee2-d98fa93da873_aria01_rgb.pt'), ('iiith_cooking_41_3', '/local/juro4948/data/egoexo4d/egoexo/features/omnivore_video/a914f836-eb7d-4ebc-a537-e8d7dbb39429_aria01_rgb.pt'), ('sfu_cooking015_4', '/local/juro4948/data/egoexo4d/egoexo/features/omnivore_video/19912997-45b4-4c43-8209-7599079d8eed_aria01_rgb.pt'), ('iiith_cooking_40_1', '/local/juro4948/data/ego ...
# Length of paths_to_mp4s: 342

# %%
from tqdm.notebook import tqdm

# %%
import cv2

print("OpenCV version:", cv2.__version__)
print("OpenCV CUDA enabled devices:", cv2.cuda.getCudaEnabledDeviceCount())
# Out:
# OpenCV version: 4.9.0
# OpenCV CUDA enabled devices: 0

# %%
import cv2

if cv2.cuda.getCudaEnabledDeviceCount() > 0:
    print("OpenCV is using GPU acceleration")
else:
    print("OpenCV is not using GPU acceleration")
# Out:
# OpenCV is not using GPU acceleration

# %%
DATASET = os.path.expanduser("egoexo4d/")
url_imgs = DATASET+"preprocessed_old/imgs/"

# incomplete = 0
# completed = 0
# no_annotations = 0
# take_names_to_download = []
# # first get the number of videos to process
# for take_name, video_file in paths_to_mp4s:
#     take_id = get_take_id_from_name(take_name)
#     if take_id == None:
#         no_annotations += 1
#         continue
    
#     video_id = video_file.split('/')[-1].split('.mp4')[0]
#     if os.path.exists(os.path.join(url_imgs, take_name, video_id)) and len(os.listdir(os.path.join(url_imgs, take_name, video_id))) == take_to_vlen[take_name]:
#             completed += 1 
#     else:
#         take_names_to_download.append(take_name)
#         incomplete += 1

# print(f'Status of frames extracted:')
# print(f'Incomplete: {incomplete}, Completed: {completed}, No annotations: {no_annotations}')
        
# count = 0
# for take_name, video_file in tqdm(paths_to_mp4s):
#     if take_name not in take_names_to_download:
#         continue
#     take_id = get_take_id_from_name(take_name)

#     # read in the video
#     vid = cv2.VideoCapture(video_file)
#     ret, im = vid.read()
#     n_frames = take_to_vlen[take_name]

#     # make directory to save frames
#     if not os.path.exists(os.path.join(url_imgs, take_name, video_id)):
#         if not os.path.exists(os.path.join(url_imgs, take_name)):
#             os.mkdir(os.path.join(url_imgs, take_name))
#         os.mkdir(os.path.join(url_imgs, take_name, video_id))
 
#     print(f'Extracting frames from {video_file}...')
#     count += 1
#     for i in range(int(n_frames/downsample_rate)):
#         if i % 1000 == 0:
#             print(i, "of", n_frames/downsample_rate)

#         if i > n_frames:
#             print("New video")
#             break

#         vid.set(cv2.CAP_PROP_POS_FRAMES, i*downsample_rate)
#         ret, im = vid.read()
#         if not ret:
#             print("No image")
#             break

#         im = cv2.resize(im, (256,256))
#         ret = cv2.waitKey(1)
#         if ret >= 0:
#             break
        
#         # TODO: Blake: modify directory structure
#         # Current: egoexo4d/preprocessed/imgs/fair_cooking_07_4/aria01_214-1
#         # Desired: egoexo4d/preprocessed/imgs/aria-214-1/fair_cooking_07_4

#         # Later: egoexo4d/preprocessed/imgs/gopro/fair_cooking_07_4
#         fn = "{}{}/{}/{}_{}.jpg".format(url_imgs, take_name, video_id, 'img', i*downsample_rate)  # TODO: change path # TODO: later for gopro we will need to downsample by half to match aria frame rate
#         success = cv2.imwrite(fn, im)
#         if success == False:
#             print('error')
#     print('Done')

# # print(f'Fail: {fail_count}, Success: {success_count}')
# print(f'Frames extracted from {count} videos.')

# %% [markdown]
# # Preprocess annotations

# %% [markdown]
# Todo: format the data so that i can easily run bridge-prompt on it: https://github.com/ttlmh/Bridge-Prompt/blob/master/train.py

# %% [markdown]
# Below cell saves labels that look like this in the raw egoexo folder:
# - start_frame end_frame action_label
# - 65 98 get_noodles
# - 98 396 add_the_noodles_in_the_boiling_water
# - 433 833 stir_noodles_in_the_pot
# - 902 945 get_napkin
# - 1235 1509 stir_noodles_in_the_pot

# %%
# first, must convert the json labels to framestamp-by-framestamp labels and save in raw egoexo takes folder
# note: must make a symlink from GraVi-T annotations folder to preprocessed/annotations/gravit-groundTruth

DATASET = "egoexo4d/"
preprocessed_output_path = DATASET+"preprocessed/annotations/gravit-groundTruth/"
success_count = 0
fail_count = 0
take_dir = 'egoexo4d/egoexo/takes'

if not os.path.exists(preprocessed_output_path):
    os.makedirs(preprocessed_output_path)

for take_name, video_file in paths_to_mp4s:
    take_id = get_take_id_from_name(take_name)
    take_root = os.path.join(take_dir, take_name, 'frame_aligned_videos')
    if take_id == None:
        print(f'Labels not found for take: {video_file} ... Skipping....')
        fail_count += 1
        continue
    else:
        success_count += 1

    label_data = anns[take_id]['segments']

    # Create a list to store the formatted label entries
    formatted_labels = []
    n_frames = take_to_vlen[take_name]
 
    # Calculate frame numbers for each label and create the formatted entries
    for i, label in enumerate(label_data):
        start_time = label['start_time']
        end_time = label['end_time']
        
        if i == 0: # Handle starting frames without annotations
            if start_time > 0:
                formatted_labels.append(f"0 {int(start_time * frame_rate)} action_start")
        
        # Convert start and end times to frame numbers
        start_frame = int(start_time * frame_rate)
        end_frame = int(end_time * frame_rate)
        
        # Get the action label
        action_label = label['step_name']
        words = action_label.split()
        action_label = "_".join([w.lower() for w in words])
        
        # Create the formatted entry and add it to the list
        formatted_entry = f"{start_frame} {end_frame} {action_label}"
        formatted_labels.append(formatted_entry)

    # Handle ending frames without annotations
    start_of_action_end = formatted_labels[-1].split(' ')[1]
    formatted_labels.append(start_of_action_end + ' ' + str(n_frames) + ' ' + 'action_end')

    # # Define the output file path
    output_file_path = os.path.join(take_root, f"{frame_rate}fps_formatted_labels.txt") # The formatted labels should be matched with all the videos of the take bc they are supposed to be frame-aligned
    
    # Write the formatted labels to the output file
    with open(output_file_path, 'w') as output_file:
        for entry in formatted_labels:
            output_file.write(entry + '\n')
    print(f'Formatted labels saved to {output_file_path}')
    print('-------------')

print(f'Fail: {fail_count}, Success: {success_count}')
print(f"Formatted labels saved to {output_file_path}")
# Out:
# Formatted labels saved to egoexo4d/egoexo/takes/minnesota_cooking_050_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/indiana_cooking_03_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/georgiatech_cooking_02_02_6/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_57_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_120_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_122_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_146_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/upenn_0714_Cooking_1_3/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_125_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/indiana_cooking_27_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_26_1/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/sfu_cooking020_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/upenn_0714_Cooking_7_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_112_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_65_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_123_6/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_82_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/upenn_0702_Cooking_4_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/minnesota_cooking_074_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_89_6/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_64_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_60_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_124_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/georgiatech_cooking_04_01_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/upenn_0714_Cooking_1_5/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/indiana_cooking_20_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_18_1/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/georgiatech_cooking_14_02_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/upenn_0710_Cooking_4_3/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_120_6/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_84_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_13_1/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_142_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/upenn_0710_Cooking_4_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_55_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/fair_cooking_08_8/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_109_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_132_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/georgiatech_cooking_09_02_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/georgiatech_cooking_04_02_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/sfu_cooking028_12/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_01_1/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_02_1/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/fair_cooking_05_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/uniandes_cooking_009_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/indiana_cooking_09_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/utokyo_omelet_6_1001_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_29_3/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_131_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/georgiatech_cooking_11_01_6/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_138_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/upenn_0711_Cooking_1_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_131_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/sfu_cooking015_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_120_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/georgiatech_cooking_13_02_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/sfu_cooking023_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_90_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_43_3/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_123_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_135_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_128_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/fair_cooking_05_6/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_56_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_78_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/georgiatech_cooking_10_01_5/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/upenn_0711_Cooking_2_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/indiana_cooking_26_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_05_1/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_100_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/georgiatech_cooking_09_01_3/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_79_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_07_1/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_30_1/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/indiana_cooking_22_3/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/upenn_0702_Cooking_2_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_16_1/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_41_3/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/georgiatech_cooking_10_01_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_25_3/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/indiana_cooking_16_3/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/georgiatech_cooking_02_01_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/upenn_0702_Cooking_3_3/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_29_1/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_19_1/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/sfu_cooking_005_6/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_97_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_130_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_44_1/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/fair_cooking_05_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/indiana_cooking_01_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_130_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/upenn_0712_Cooking_1_3/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/minnesota_cooking_061_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/georgiatech_cooking_14_01_6/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_45_3/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/georgiatech_cooking_02_02_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_41_1/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/indiana_cooking_12_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/upenn_0714_Cooking_7_3/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_90_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_20_1/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_57_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/georgiatech_cooking_10_02_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/georgiatech_cooking_01_01_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/georgiatech_cooking_09_01_6/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_117_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/sfu_cooking_002_7/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/fair_cooking_06_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/fair_cooking_08_10/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_40_1/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_23_1/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/georgiatech_cooking_01_01_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_128_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_137_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/minnesota_cooking_010_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_59_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/upenn_0702_Cooking_3_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/minnesota_cooking_060_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/indiana_cooking_23_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/upenn_0711_Cooking_6_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_65_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_11_1/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_122_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_43_1/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/georgiatech_cooking_09_02_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/georgiatech_cooking_13_02_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/fair_cooking_06_6/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_134_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/uniandes_cooking_009_6/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_25_1/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_110_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/georgiatech_cooking_11_01_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_125_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_132_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/georgiatech_cooking_06_02_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_32_1/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/fair_cooking_06_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_147_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_112_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/sfu_cooking029_8/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/sfu_cooking025_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_04_1/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_75_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_71_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/uniandes_cooking_009_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_109_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/georgiatech_cooking_02_01_6/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_03_1/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_99_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_81_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_89_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_85_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/upenn_0702_Cooking_1_3/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/georgiatech_cooking_01_02_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_118_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_116_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_142_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_148_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/indiana_cooking_10_5/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_89_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_117_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_111_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_03_3/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_111_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/upenn_0702_Cooking_2_3/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/fair_cooking_08_6/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_149_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_84_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_108_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_108_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_05_3/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_06_1/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_28_1/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/georgiatech_cooking_01_02_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_116_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/sfu_cooking031_10/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/upenn_0712_Cooking_4_3/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/georgiatech_cooking_11_02_3/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_124_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_05_5/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/indiana_cooking_21_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_71_6/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/minnesota_cooking_030_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_60_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_45_1/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/fair_cooking_07_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_115_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_123_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_110_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/georgiatech_cooking_06_02_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/fair_cooking_07_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_12_1/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/georgiatech_cooking_14_01_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/georgiatech_cooking_10_02_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/georgiatech_cooking_04_02_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/fair_cooking_08_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/utokyo_omelet_12_1001_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/upenn_0714_Cooking_5_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/sfu_cooking022_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_145_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/georgiatech_cooking_02_02_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_77_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_31_3/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/indiana_cooking_03_3/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/upenn_0711_Cooking_6_5/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_14_1/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_98_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/sfu_cooking017_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_31_1/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_99_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/upenn_0711_Cooking_3_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/georgiatech_cooking_06_03_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/fair_cooking_08_4/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_92_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_08_1/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_141_2/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/iiith_cooking_24_1/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Formatted labels saved to egoexo4d/egoexo/takes/sfu_cooking_009_7/frame_aligned_videos/30fps_formatted_labels.txt
# -------------
# Fail: 0, Success: 219
# Formatted labels saved to egoexo4d/egoexo/takes/sfu_cooking_009_7/frame_aligned_videos/30fps_formatted_labels.txt

# %% [markdown]
# Next, preprocess the labels to npy list where idx of label corresponds to idx of the video frame

# %%
# list of text labels
"""
this one iterates through all the annotations, reads the labels created above in 1. and creates an array of length n_frames where each 
element in the array is the string action label for the corresponding frame. 
It also forward fills the action labels so there are no gaps between actions
"""

import pandas as pd
import numpy as np

DATASET = os.path.expanduser("egoexo4d/")
annotation_output_path = DATASET+"preprocessed/annotations/gravit-groundTruth/"
if os.path.exists(annotation_output_path) == False:
    os.makedirs(annotation_output_path)

# also save to Gravi-T repo
annotation_output_path = '/home/juro4948/gravit/GraVi-T/data/annotations/egoexo-omnivore-aria/groundTruth'
os.makedirs(annotation_output_path, exist_ok=True)

success_count = 0
fail_count = 0
fail = 0
for take_name, video_file in paths_to_mp4s:
    take_id = get_take_id_from_name(take_name)
    if take_id == None:
        print(f'Labels not found for take: {video_file} ... Skipping....')
        continue

    take_root = f"egoexo4d/egoexo/takes/{take_name}/frame_aligned_videos/"
    take_root_downscaled = f"egoexo4d/egoexo/takes/{take_name}/frame_aligned_videos/downscaled/448"

    if os.path.exists(take_root) == False:
        continue
    if os.path.exists(os.path.join(take_root, f"{frame_rate}fps_formatted_labels.txt")) == False:
        continue

    # try:
    #     # Blake: Extract video from downscaled/448 directory
    #     video_file = [fn for fn in os.listdir(take_root_downscaled) if (ego_rgb_code in fn and camera in fn)][0] # TODO: same as above, we should parse takes.json to get the ego_rgb_code for this take. From visual inspection it seems that it's always 214-1, but we should be sure.   
    # except:
    #     continue # if we didn't download the take, skip

    # Define the path to the formatted labels text file
    formatted_labels_path = os.path.join(take_root, f"{frame_rate}fps_formatted_labels.txt")

    # Load the formatted labels from the text file
    formatted_labels = []
    with open(formatted_labels_path, 'r') as file:
        for line in file:
            line = line.strip()
            if line:
                parts = line.split()
                start_frame, end_frame = int(parts[0]), int(parts[1])
                action_label = ' '.join(parts[2:])
                formatted_labels.append((start_frame, end_frame, action_label))

    # Calculate the total number of frames - need to lead the video or count num_files in the directory
    if take_name not in take_to_vlen.keys():
        print(f'No video found for take: {take_name} ... Skipping....')
        continue

    total_frames = take_to_vlen[take_name]

    # Create an array to store the labels for each frame
    video_labels = np.empty(total_frames, dtype=object)
    video_labels.fill("")

    # Assign labels to corresponding frames
    this_failed = 0
    for start_frame, end_frame, action_label in formatted_labels:
        if action_label == 'action_start' and start_frame != 0:
            print('Error with action_start label. Not at beginning of video.')
            fail += 1
            this_failed = 1
            break
        elif action_label == 'action_end' and end_frame != total_frames:
            print('Error with action_end label. Not at end of video.')
            print(f'end_frame: {end_frame}, total_frames: {total_frames}')
            fail += 1
            this_failed = 1
            break
    
        video_labels[start_frame:end_frame + 1] = action_label

    if this_failed == 1:
        print(f'Failed for take: {take_name}')
        continue

    #### fill empty strings with a none label

    video_labels[video_labels == ""] = np.nan
    ### forwardfill empty strings with the previous label
    video_labels = pd.Series(video_labels).fillna(method='ffill').values


    # Define the output file path for the .npy file
    # output_file_path = os.path.join(take_root, f"{frame_rate}fps_longform_annotations.npy")
    output_file_path = os.path.join(annotation_output_path, f'{take_name}.txt')


    # Write the formatted labels to the output file
    with open(output_file_path, 'w') as output_file:
        for entry in video_labels:
            output_file.write(entry + '\n')
# Out:
# /tmp/ipykernel_3999664/384748963.py:93: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   video_labels = pd.Series(video_labels).fillna(method='ffill').values

# %%
save_root = '../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id' # label directory for BrP

if not os.path.exists(save_root):
    os.mkdir(save_root)
    print('Created directory')

save_root = save_root + '/30fps'
if not os.path.exists(save_root):
    os.mkdir(save_root)
    print(f'Created directory: {save_root}')

# %% [markdown]
# Check that the label length matches the video length

# %%
import os
import numpy as np

# Define the directory where the annotations and frames are saved
annotations_dir = "../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps"
frames_dir = "egoexo4d/preprocessed_old/imgs"

# Get the list of annotation files
annotation_files = os.listdir(annotations_dir)

# Iterate over each annotation file
for annotation_file in annotation_files:
    # Get the session name from the annotation file name
    session_name = annotation_file.split(".")[0]
    
    # Load the annotations
    annotations = np.load(os.path.join(annotations_dir, annotation_file), allow_pickle=True)
    
    # Get the number of frames saved for the session
    frames_path = os.path.join(frames_dir, session_name)
    if len(os.listdir(frames_path)) != 1:
        print(f"Multiple folders found for session {session_name}. this means there are multiple aria or gopro videos for this session. Choosing the first...")
    
    frames_path = os.path.join(frames_path, os.listdir(frames_path)[0])
    num_frames = len(os.listdir(frames_path))

    # print(len(annotations), num_frames)
    
    # Compare the lengths of the annotations and the frames
    if len(annotations) == num_frames:
        pass
    else:
        print(f"The length of annotations does not match the number of frames for session {session_name}")
print('Done checking')
# Out:
# Multiple folders found for session fair_cooking_05_4. this means there are multiple aria or gopro videos for this session. Choosing the first...
# Done checking

# %% [markdown]
# # Now we must re-arrange the label vocabulary to start the unique ids at 0

# %%
# build a dictionary of the mapping between {int: action class}
# save as json
"""
This goes through all the annotations saved in 1) and gets all of the unique action classes and builds a dictionary to transition between the action string and corresponding integer label
"""

actions = set()
vocab = {}

# TODO: Blake: hange this loop to the loop above
for take_id in anns.keys():
    take_name = anns[take_id]['take_name']
    take_root = f"egoexo4d/egoexo/takes/{take_name}/frame_aligned_videos/"  # TODO: cahnge
    
    if os.path.exists(take_root) == False:
        continue

    # Define the path to the formatted labels text file
    formatted_labels_path = os.path.join(take_root, f"{frame_rate}fps_formatted_labels.txt")

    if os.path.exists(formatted_labels_path) == False:
        print(f'File does not exist: {formatted_labels_path}')
        continue
    with open(formatted_labels_path, 'r') as file:
        for line in file:
            line = line.strip()
            if line:
                parts = line.split()
                start_frame, end_frame = int(parts[0]), int(parts[1])
                action_label = ' '.join(parts[2:])
                if action_label not in actions:
                    actions.add(action_label)

formatted_labels = list(actions)

i = 0
for action in formatted_labels:
    vocab[i] = action
    i += 1

# save
with open('../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/mapping_adj.json', 'w') as fp:
    json.dump(vocab, fp)

print(vocab)
print('action_start' in vocab.values())
print('action_end' in vocab.values())
print(f'Num classes: {len(vocab)}')
# Out:
# {0: 'add_peanut_butter', 1: 'put_away_garlic_cloves', 2: 'put_away_soy_sauce', 3: 'get_onions', 4: 'cut_scallion', 5: 'whisk_the_mix_of_ingredients', 6: 'get_napkin', 7: 'wait_until_water_boils', 8: 'wash_measuring_tool_(scoop_or_spoon_or_cup)', 9: 'put_away_kitchen_towel', 10: 'toss_the_mixture', 11: 'put_away_nutmeg', 12: 'wash_sieve', 13: 'cut_tomato', 14: 'put_away_oyster_sauce', 15: 'get_white_pepper', 16: 'get_dried_herbs', 17: 'put_away_spoon', 18: 'roll_the_sushi_up_from_the_bottom_using_your_mat', 19: 'add_the_coffee_grounds_to_the_filter_in_the_pour-over_device.', 20: 'get_pot_holder', 21: 'wash_cherry_tomatoes', 22: 'add_flour_to_surface', 23: 'tilt_and_rotate_skillet_to_allow_uncooked_egg_to_flow_into_empty_spaces', 24: 'get_measuring_tool_(scoop_or_spoon_or_cup)', 25: 'get_bell_peppers', 26: 'close_the_instant_coffee_jar', 27: 'wash_fork', 28: 'get_spatula', 29: 'put_away_almonds', 30: 'stir_coffee_with_water_mixture', 31: 'get_vinegar', 32: 'get_plate', 33: 'get_cinnamon_stick', 34: 'add_raw_fish', 35: 'whisk_egg', 36: 'get_honey', 37: 'add_cloves_to_tea', 38: 'put_away_eggs', 39: 'drain_the_noodles_into_a_strainer', 40: 'turn_on_the_stove', 41: 'set_a_timer', 42: 'fold_the_omelet_in_half', 43: 'cut_lime', 44: 'put_away_napkin', 45: 'visually_inspect_the_recipe', 46: 'put_away_skillet_or_frying_pan_or_wok', 47: 'wash_napkin', 48: 'wash_tea_bag', 49: 'stir_the_dressing_mixture', 50: 'stir_milk_with_a_spoon_to_mix_well_with_water_and_tea', 51: 'add_hot_sauce', 52: 'fill_an_electric_kettle_with_water', 53: 'get_chili_powder', 54: 'add_mustard_leaves_to_a_bowl', 55: 'get_oil', 56: 'add_turmeric_powder', 57: 'add_ginger_garlic_paste_to_a_mixing_bowl', 58: 'remove_seeds_from_tomato', 59: 'add_vinegar', 60: 'get_skillet_or_frying_pan_or_wok', 61: 'wash_fresh_parsley', 62: 'cut_lettuce', 63: 'wash_hands', 64: 'put_away_beef', 65: 'place_water_on_the_stove', 66: 'remove_seeds_from_bell_peppers', 67: 'add_onion_powder_to_a_mixing_bowl', 68: 'put_away_tea_leaves', 69: 'pour_the_tea_into_the_cup', 70: 'get_lemon_juice', 71: 'continue_steaming_until_the_milk_reaches_the_desired_temperature', 72: 'get_chopping_board', 73: 'cut_nutmeg', 74: 'get_pepper', 75: 'wash_lettuce', 76: 'get_cabbage', 77: 'cut_spring_onions', 78: 'get_a_milk_frothing_pitcher', 79: 'close_the_lid_of_the_coffee_maker', 80: 'put_away_chopsticks', 81: 'get_measuring_cup', 82: 'add_olive_oil_to_a_skillet', 83: 'get_peeler', 84: 'add_lime_juice_to_a_mixing_bowl', 85: 'get_sesame_seeds', 86: 'add_pepper', 87: 'stir_the_salad_mixture', 88: 'add_lettuce', 89: 'add_radish', 90: 'pour_the_coffee_into_a_cup_or_mug', 91: 'add_black_pepper', 92: 'get_tea_bag', 93: 'add_carrots', 94: 'add_cooked_tomatoes_into_the_skillet', 95: 'wash_noodles', 96: 'add_ketchup', 97: 'add_honey', 98: 'knead_dough', 99: 'pour_coffee_beans_into_the_grinder', 100: 'wash_scallion', 101: 'put_away_timer', 102: 'get_spoon', 103: 'wash_skillet_or_frying_pan_or_wok', 104: 'get_pitcher', 105: 'put_away_tea_bag', 106: 'put_away_honey', 107: 'cook_until_the_egg_is_cooked', 108: 'add_tomato_paste_to_a_skillet', 109: 'add_agave_to_a_mixing_bowl', 110: 'add_garlic_paste', 111: 'reduce_water_level', 112: 'wash_tomato', 113: 'get_tomato_sauce', 114: 'put_away_cutting_board', 115: 'wash_carrots', 116: 'action_start', 117: 'remove_cinnamon_from_the_milk', 118: 'put_away_rice_vinegar', 119: 'get_whisk', 120: 'wash_onions', 121: 'check_heat_of_the_skillet', 122: 'add_cinnamon_stick', 123: 'add_lemon_juice', 124: 'get_cardamom', 125: 'get_scallion', 126: 'put_away_carrots', 127: 'turn_off_the_steam_wand_and_remove_it_from_the_pitcher.', 128: 'cut_beef', 129: 'get_a_bowl', 130: 'put_away_fork', 131: 'wash_pot_or_saucepan', 132: 'measure_the_temperature_using_an_instant_thermometer', 133: 'put_away_spring_onions', 134: 'get_kitchen_tong', 135: 'get_cinnamon_powder', 136: 'peel_carrots', 137: 'wait_until_milk_boils', 138: 'add_feta_cheese', 139: 'strain_the_coffee_into_a_cup', 140: 'put_away_cinnamon_powder',  ...
# True
# True
# Num classes: 497

# %%
# converts json to txt file
# Save action mapping as txt file for BrP

with open('../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/mapping_adj.json', 'r') as fp:
    mapping = json.load(fp)

# Process and convert to the desired format
output_lines = []
for key, value in mapping.items():
    words = value.split()
    action_name = "_".join([w.lower() for w in words])
    output_lines.append(f"{key} {action_name}")

# Save the result to a text file
out = '../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/mapping.txt'
with open(out, "w") as output_file:
    output_file.write("\n".join(output_lines))

# # Save the result to a text file
# out = '/home/juro4948/gravit/GraVi-T/data/annotations/egoexo-omnivore-aria/mapping.txt'
# with open(out, "w") as output_file:
#     output_file.write("\n".join(output_lines))

print(f"Conversion complete. Output saved as {out}.")
# Out:
# Conversion complete. Output saved as /home/juro4948/gravit/GraVi-T/data/annotations/egoexo-omnivore-aria/mapping.txt.

# %%
# build reverse mapping
action_to_int = {}
for key, value in mapping.items():
    action_to_int[value] = key

action_to_int['action_start']
# Out:
# '116'

# %%
# save integer labels as npy files for BridgePrompt
url_imgs = DATASET+"preprocessed_old/imgs/"

import numpy as np

for take_name, video_file in paths_to_mp4s:
    take_id = get_take_id_from_name(take_name)
    if take_id == None:
        print(f'Labels not found for take: {video_file} ... Skipping....')
        continue

    take_root = f"egoexo4d/egoexo/takes/{take_name}/frame_aligned_videos/"


    # Define the path to the formatted labels text file
    formatted_labels_path = os.path.join(take_root, f"{frame_rate}fps_formatted_labels.txt")

    # Load the formatted labels from the text files
    if os.path.exists(formatted_labels_path) == False:
        print(f'File does not exist: {formatted_labels_path}')
        continue

    formatted_labels = []
    with open(formatted_labels_path, 'r') as file:
        for line in file:
            line = line.strip()
            if line:
                parts = line.split()
                start_frame, end_frame = int(parts[0]), int(parts[1])
                action_label = ' '.join(parts[2:])
                formatted_labels.append((start_frame, end_frame, action_label))

   
    total_frames = take_to_vlen[take_name] # take num frames based on video
    video_id = video_file.split('.mp4')[0]

    # # now read in list of the frames to choose
    # imgs = os.listdir("{}{}/{}".format(url_imgs, take_name, video_id))
    # frame_nums = [int(fn.split('img_')[1].split('.jpg')[0]) for fn in imgs] 
    # frame_nums = sorted(frame_nums)

    # Create an array to store the labels for each frame
    video_labels = np.empty(total_frames, dtype=object)
    video_labels.fill("")

    # Assign labels to corresponding frames
    for start_frame, end_frame, action_label in formatted_labels:
        video_labels[start_frame:end_frame + 1] = action_label

    # video_labels = video_labels[frame_nums]

    # forwardfill empty strings with the previous label
    video_labels[video_labels == ""] = np.nan
    video_labels = pd.Series(video_labels).fillna(method='ffill').values

    # Take integer labels
    video_labels = np.array([action_to_int[label] for label in video_labels])
    print(video_labels)
    
# 
    # Define the output file path for the .npy file
    output_file_path = os.path.join(save_root, f"{take_name}.npy")

    # Save the video labels as a .npy file
    np.save(output_file_path, video_labels)

    print(f"Video labels have been saved to {output_file_path}")
# Out:
# /tmp/ipykernel_3999664/2208023064.py:54: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   video_labels = pd.Series(video_labels).fillna(method='ffill').values
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/minnesota_cooking_050_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/indiana_cooking_03_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/georgiatech_cooking_02_02_6.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_57_2.npy
# ['116' '116' '116' ... '335' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_120_4.npy
# ['116' '116' '116' ... '175' '175' '175']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_122_4.npy
# ['116' '116' '116' ... '335' '335' '335']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_146_2.npy
# ['458' '458' '458' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/upenn_0714_Cooking_1_3.npy
# ['60' '60' '60' ... '335' '335' '335']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_125_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/indiana_cooking_27_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_26_1.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/sfu_cooking020_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/upenn_0714_Cooking_7_2.npy
# ['340' '340' '340' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_112_4.npy
# ['40' '40' '40' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_65_4.npy
# ['116' '116' '116' ... '69' '69' '69']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_123_6.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_82_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/upenn_0702_Cooking_4_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/minnesota_cooking_074_2.npy
# ['340' '340' '340' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_89_6.npy
# ['116' '116' '116' ... '335' '335' '335']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_64_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_60_2.npy
# ['72' '72' '72' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_124_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/georgiatech_cooking_04_01_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/upenn_0714_Cooking_1_5.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/indiana_cooking_20_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_18_1.npy
# ['280' '280' '280' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/georgiatech_cooking_14_02_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/upenn_0710_Cooking_4_3.npy
# ['267' '267' '267' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_120_6.npy
# ['40' '40' '40' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_84_4.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_13_1.npy
# ['116' '116' '116' ... '402' '402' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_142_2.npy
# ['116' '116' '116' ... '458' '458' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/upenn_0710_Cooking_4_2.npy
# ['60' '60' '60' ... '335' '335' '335']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_55_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/fair_cooking_08_8.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_109_2.npy
# ['60' '60' '60' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_132_4.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/georgiatech_cooking_09_02_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/georgiatech_cooking_04_02_4.npy
# ['366' '366' '366' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/sfu_cooking028_12.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_01_1.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_02_1.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/fair_cooking_05_4.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/uniandes_cooking_009_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/indiana_cooking_09_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/utokyo_omelet_6_1001_4.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_29_3.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_131_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/georgiatech_cooking_11_01_6.npy
# ['452' '452' '452' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_138_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/upenn_0711_Cooking_1_2.npy
# ['60' '60' '60' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_131_4.npy
# ['40' '40' '40' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/sfu_cooking015_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_120_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/georgiatech_cooking_13_02_2.npy
# ['338' '338' '338' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/sfu_cooking023_2.npy
# ['129' '129' '129' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_90_4.npy
# ['366' '366' '366' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_43_3.npy
# ['72' '72' '72' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_123_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_135_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_128_2.npy
# ['116' '116' '116' ... '331' '331' '331']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/fair_cooking_05_6.npy
# ['150' '150' '150' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_56_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_78_2.npy
# ['402' '402' '402' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/georgiatech_cooking_10_01_5.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/upenn_0711_Cooking_2_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/indiana_cooking_26_4.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_05_1.npy
# ['229' '229' '229' ... '87' '87' '87']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_100_4.npy
# ['116' '116' '116' ... '387' '387' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/georgiatech_cooking_09_01_3.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_79_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_07_1.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_30_1.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/indiana_cooking_22_3.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/upenn_0702_Cooking_2_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_16_1.npy
# ['199' '199' '199' ... '87' '87' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_41_3.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/georgiatech_cooking_10_01_2.npy
# ['72' '72' '72' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_25_3.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/indiana_cooking_16_3.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/georgiatech_cooking_02_01_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/upenn_0702_Cooking_3_3.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_29_1.npy
# ['116' '116' '116' ... '275' '275' '275']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_19_1.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/sfu_cooking_005_6.npy
# ['366' '366' '366' ... '87' '87' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_97_2.npy
# ['262' '262' '262' ... '335' '335' '335']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_130_4.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_44_1.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/fair_cooking_05_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/indiana_cooking_01_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_130_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/upenn_0712_Cooking_1_3.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/minnesota_cooking_061_2.npy
# ['13' '13' '13' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/georgiatech_cooking_14_01_6.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_45_3.npy
# ['226' '226' '226' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/georgiatech_cooking_02_02_4.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_41_1.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/indiana_cooking_12_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/upenn_0714_Cooking_7_3.npy
# ['60' '60' '60' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_90_2.npy
# ['116' '116' '116' ... '483' '483' '483']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_20_1.npy
# ['116' '116' '116' ... '346' '346' '346']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_57_4.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/georgiatech_cooking_10_02_4.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/georgiatech_cooking_01_01_4.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/georgiatech_cooking_09_01_6.npy
# ['40' '40' '40' ... '275' '275' '275']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_117_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/sfu_cooking_002_7.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/fair_cooking_06_4.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/fair_cooking_08_10.npy
# ['116' '116' '116' ... '335' '335' '335']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_40_1.npy
# ['116' '116' '116' ... '87' '87' '87']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_23_1.npy
# ['280' '280' '280' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/georgiatech_cooking_01_01_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_128_4.npy
# ['452' '452' '452' ... '335' '335' '335']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_137_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/minnesota_cooking_010_2.npy
# ['3' '3' '3' ... '335' '335' '335']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_59_2.npy
# ['294' '294' '294' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/upenn_0702_Cooking_3_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/minnesota_cooking_060_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/indiana_cooking_23_4.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/upenn_0711_Cooking_6_4.npy
# ['116' '116' '116' ... '87' '87' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_65_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_11_1.npy
# ['40' '40' '40' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_122_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_43_1.npy
# ['280' '280' '280' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/georgiatech_cooking_09_02_4.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/georgiatech_cooking_13_02_4.npy
# ['315' '315' '315' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/fair_cooking_06_6.npy
# ['437' '437' '437' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_134_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/uniandes_cooking_009_6.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_25_1.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_110_2.npy
# ['280' '280' '280' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/georgiatech_cooking_11_01_4.npy
# ['340' '340' '340' ... '69' '69' '69']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_125_4.npy
# ['116' '116' '60' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_132_2.npy
# ['280' '280' '280' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/georgiatech_cooking_06_02_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_32_1.npy
# ['282' '282' '282' ... '131' '131' '131']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/fair_cooking_06_2.npy
# ['60' '60' '60' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_147_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_112_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/sfu_cooking029_8.npy
# ['338' '338' '338' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/sfu_cooking025_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_04_1.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_75_2.npy
# ['60' '60' '60' ... '275' '275' '275']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_71_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/uniandes_cooking_009_4.npy
# ['199' '199' '199' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_109_4.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/georgiatech_cooking_02_01_6.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_03_1.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_99_4.npy
# ['40' '40' '40' ... '178' '178' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_81_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_89_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_85_2.npy
# ['60' '60' '60' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/upenn_0702_Cooking_1_3.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/georgiatech_cooking_01_02_4.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_118_2.npy
# ['338' '338' '338' ... '346' '346' '346']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_116_4.npy
# ['125' '125' '125' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_142_4.npy
# ['437' '437' '437' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_148_2.npy
# ['116' '116' '116' ... '387' '387' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/indiana_cooking_10_5.npy
# ['129' '129' '129' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_89_4.npy
# ['150' '150' '150' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_117_4.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_111_4.npy
# ['308' '308' '308' ... '69' '69' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_03_3.npy
# ['116' '40' '40' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_111_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/upenn_0702_Cooking_2_3.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/fair_cooking_08_6.npy
# ['116' '116' '116' ... '474' '474' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_149_2.npy
# ['32' '32' '32' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_84_2.npy
# ['32' '32' '32' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_108_4.npy
# ['40' '40' '40' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_108_2.npy
# ['116' '116' '116' ... '87' '87' '87']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_05_3.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_06_1.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_28_1.npy
# ['280' '280' '280' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/georgiatech_cooking_01_02_2.npy
# ['60' '60' '60' ... '335' '335' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_116_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/sfu_cooking031_10.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/upenn_0712_Cooking_4_3.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/georgiatech_cooking_11_02_3.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_124_4.npy
# ['315' '315' '315' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_05_5.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/indiana_cooking_21_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_71_6.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/minnesota_cooking_030_2.npy
# ['366' '366' '366' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_60_4.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_45_1.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/fair_cooking_07_4.npy
# ['60' '60' '60' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_115_2.npy
# ['231' '231' '231' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_123_4.npy
# ['340' '340' '340' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_110_4.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/georgiatech_cooking_06_02_4.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/fair_cooking_07_2.npy
# ['116' '116' '116' ... '335' '335' '335']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_12_1.npy
# ['437' '437' '437' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/georgiatech_cooking_14_01_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/georgiatech_cooking_10_02_2.npy
# ['282' '282' '282' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/georgiatech_cooking_04_02_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/fair_cooking_08_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/utokyo_omelet_12_1001_4.npy
# ['116' '116' '116' ... '347' '347' '347']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/upenn_0714_Cooking_5_2.npy
# ['116' '116' '116' ... '458' '458' '458']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/sfu_cooking022_2.npy
# ['72' '72' '72' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_145_2.npy
# ['280' '280' '280' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/georgiatech_cooking_02_02_2.npy
# ['199' '199' '199' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_77_2.npy
# ['116' '116' '116' ... '87' '87' '87']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_31_3.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/indiana_cooking_03_3.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/upenn_0711_Cooking_6_5.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_14_1.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_98_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/sfu_cooking017_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_31_1.npy
# ['199' '199' '199' ... '335' '335' '335']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_99_2.npy
# ['116' '116' '116' ... '46' '46' '46']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/upenn_0711_Cooking_3_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/georgiatech_cooking_06_03_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/fair_cooking_08_4.npy
# ['72' '72' '72' ... '87' '87' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_92_2.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_08_1.npy
# ['452' '452' '452' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_141_2.npy
# ['116' '116' '116' ... '69' '69' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/iiith_cooking_24_1.npy
# ['116' '116' '116' ... '397' '397' '397']
# Video labels have been saved to ../../../home/juro4948/gravit/Bridge-Prompt/data/egoexo/action_descriptions_id/30fps/sfu_cooking_009_7.npy
